# %% [markdown]
# # EcoHome Energy Advisor - Agent Run & Evaluation
#
# In this notebook, you'll run the Energy Advisor agent with various real-world scenarios and see how it helps customers optimize their energy usage.
#
# ## Learning Objectives
# - Create the agent's instructions
# - Run the Energy Advisor with different types of questions
# - Evaluate response quality and accuracy
# - Measure tool usage effectiveness
# - Identify areas for improvement
# - Implement evaluation metrics
#
# ## Evaluation Criteria
# - **Accuracy**: Correct information and calculations
# - **Relevance**: Responses address the user's question
# - **Completeness**: Comprehensive answers with actionable advice
# - **Tool Usage**: Appropriate use of available tools
# - **Reasoning**: Clear explanation of recommendations

# %% [markdown]
# ## 1. Import and Initialize

# %%
from datetime import datetime
from agent import Agent

# %%
ECOHOME_SYSTEM_PROMPT = """You are EcoHome, an AI energy advisor for smart home owners. \
Your expertise covers solar generation, EV charging, HVAC, smart appliances, energy storage, and time-of-use electricity pricing.

Your goal is to help users minimize electricity costs, maximize solar self-consumption, and reduce energy waste \
through specific, data-driven recommendations.

Tools available to you:
- get_weather_forecast: hourly temperature, solar irradiance, and weather conditions by location
- get_electricity_prices: time-of-use (TOU) hourly rates with peak/off-peak/mid-peak windows
- query_energy_usage: historical device consumption by date range and device type
- query_solar_generation: historical solar production records
- get_recent_energy_summary: last N hours of usage and generation in one call
- search_energy_tips: retrieve efficiency tips and best practices from the knowledge base
- calculate_energy_savings: compute exact kWh and USD savings from any optimization scenario

Guidelines:
1. Always call get_weather_forecast and get_electricity_prices before making any scheduling recommendation.
2. Query historical usage or solar data when the question involves patterns, trends, or comparisons.
3. Give concrete answers: exact hours, specific temperatures (°F and °C), dollar amounts, and percentages.
4. Lead every scheduling recommendation with the optimal time window and explain why.
5. Include cost or savings figures in every recommendation — users need numbers to act.
6. Use the location from context when provided; default to typical U.S. TOU pricing when not.
7. When multiple devices compete for off-peak or solar windows, prioritize by energy intensity (kWh/cycle).
8. Keep responses concise and structured. Use short bullet points for lists of recommendations.

Example questions you can answer:
- "When should I charge my EV tomorrow to minimize cost and take advantage of solar generation?"
- "What temperature should I set my thermostat during peak hours to avoid high electricity charges?"
- "How much can I save this month by shifting my laundry and dishwasher to off-peak hours?"
"""

# %%
ecohome_agent = Agent(
    instructions=ECOHOME_SYSTEM_PROMPT,
)

# %%
response = ecohome_agent.invoke(
    question="When should I charge my electric car tomorrow to minimize cost and maximize solar power?",
    context="Location: San Francisco, CA")

# %%
print(response["messages"][-1].content)
# Out:
# To minimize cost and maximize solar power when charging your electric car tomorrow in San Francisco:
#
# - **Optimal Charging Window**: Charge your electric car during the off-peak hours for the lowest electricity rates and maximize solar power utilization.
#   - Off-Peak Hours: 12:00 AM to 6:00 AM
# - **Electricity Pricing Tomorrow**:
#   - Off-Peak Rate: $0.08 per kWh
#   - Mid-Peak Rate: $0.15 per kWh
#   - Peak Rate: $0.28 per kWh
# - **Solar Generation Forecast**:
#   - Peak Solar Hours: 7:00 AM to 6:00 PM
# - **Reasoning**:
#   - Charging during off-peak hours ensures the lowest electricity costs.
#   - Solar generation is highest during the day, aligning with the peak solar hours.
#
# By charging during the off-peak window, you can minimize costs and take advantage of solar power generation.

# %%
print("TOOLS:")
for msg in response["messages"]:
    if hasattr(msg, "tool_call_id") and msg.tool_call_id:
        print("-", msg.name)
# Out:
# TOOLS:
# - get_weather_forecast
# - get_electricity_prices

# %% [markdown]
# ## 2. Define Test Cases

# %%
test_cases = [
    {
        "id": "ev_charging_1",
        "question": "When should I charge my electric car tomorrow to minimize cost and maximize solar power?",
        "expected_tools": ["get_weather_forecast", "get_electricity_prices"],
        "expected_response": "Should recommend specific hours, mention off-peak rates, and reference solar generation window",
    },
    {
        "id": "thermostat_1",
        "question": "What temperature should I set my thermostat to on Wednesday afternoon when electricity prices spike?",
        "expected_tools": ["get_electricity_prices", "get_weather_forecast", "search_energy_tips"],
        "expected_response": "Should recommend pre-cooling before peak window, give specific setpoint in °F, and mention peak hours",
    },
    {
        "id": "usage_history_1",
        "question": "Suggest three ways I can reduce my energy use based on my usage history.",
        "expected_tools": ["get_recent_energy_summary", "search_energy_tips"],
        "expected_response": "Should list 3 specific recommendations based on device breakdown, with estimated savings per action",
    },
    {
        "id": "dishwasher_savings_1",
        "question": "How much can I save by running my dishwasher during off-peak hours instead of peak hours?",
        "expected_tools": ["get_electricity_prices", "calculate_energy_savings"],
        "expected_response": "Should compute savings in USD using peak vs off-peak rate difference and typical dishwasher kWh usage",
    },
    {
        "id": "pool_pump_1",
        "question": "What is the best time to run my pool pump this week based on the weather forecast?",
        "expected_tools": ["get_weather_forecast", "get_electricity_prices"],
        "expected_response": "Should give specific daily time windows combining off-peak rates and solar availability across 3+ days",
    },
    {
        "id": "solar_forecast_1",
        "question": "How much solar power can I expect to generate over the next 3 days?",
        "expected_tools": ["get_weather_forecast", "query_solar_generation"],
        "expected_response": "Should give a daily kWh estimate per day based on irradiance and compare to historical average",
    },
    {
        "id": "hvac_heatwave_1",
        "question": "How should I manage my HVAC system during a heat wave to keep costs down?",
        "expected_tools": ["get_weather_forecast", "get_electricity_prices", "search_energy_tips"],
        "expected_response": "Should recommend pre-cooling schedule, specific setpoints, and HVAC efficiency tips with cost impact",
    },
    {
        "id": "laundry_scheduling_1",
        "question": "When is the best time to run my washing machine and dryer this weekend?",
        "expected_tools": ["get_electricity_prices", "get_weather_forecast"],
        "expected_response": "Should suggest specific hours on Saturday/Sunday using off-peak rates and/or solar window",
    },
    {
        "id": "cost_breakdown_1",
        "question": "Give me a breakdown of my energy costs over the past week and flag any unusually high usage.",
        "expected_tools": ["query_energy_usage", "get_recent_energy_summary"],
        "expected_response": "Should show per-device kWh and cost totals, identify the highest consuming device, and flag anomalies",
    },
    {
        "id": "battery_strategy_1",
        "question": "What is the best strategy for charging and discharging my home battery this week?",
        "expected_tools": ["get_electricity_prices", "get_weather_forecast", "search_energy_tips"],
        "expected_response": "Should recommend charge during off-peak or solar peak and discharge during high-rate window with estimated savings",
    },
]

if len(test_cases) < 10:
    raise ValueError("You MUST have at least 10 test cases")

# %%
print(f"Loaded {len(test_cases)} test cases.")
# Out:
# Loaded 10 test cases.

# %% [markdown]
# ## 3. Run Agent Tests

# %%
CONTEXT = "Location: San Francisco, CA"

# %%
# Run the agent tests
# For each test case, call the agent and collect the response
# Store results for evaluation

print("=== Running Agent Tests ===")
test_results = []

for i, test_case in enumerate(test_cases):
    print(f"\nTest {i+1}: {test_case['id']}")
    print(f"Question: {test_case['question']}")
    print("-" * 50)
    
    try:
        # Call the agent
        response = ecohome_agent.invoke(
            question=test_case['question'],
            context=CONTEXT
        )
        
        # Store the result
        result = {
            'test_id': test_case['id'],
            'question': test_case['question'],
            'response': response,
            'expected_tools': test_case['expected_tools'],
            'expected_response': test_case['expected_response'],
            'timestamp': datetime.now().isoformat()
        }
        test_results.append(result)
                
    except Exception as e:
        print(f"Error: {e}")
        result = {
            'test_id': test_case['id'],
            'question': test_case['question'],
            'response': f"Error: {str(e)}",
            'expected_tools': test_case['expected_tools'],
            'expected_response': test_case['expected_response'],
            'timestamp': datetime.now().isoformat(),
            'error': str(e)
        }
        test_results.append(result)

print(f"\nCompleted {len(test_results)} tests")
# Out:
# === Running Agent Tests ===
#
# Test 1: ev_charging_1
# Question: When should I charge my electric car tomorrow to minimize cost and maximize solar power?
# --------------------------------------------------
#
# Test 2: thermostat_1
# Question: What temperature should I set my thermostat to on Wednesday afternoon when electricity prices spike?
# --------------------------------------------------
#
# Test 3: usage_history_1
# Question: Suggest three ways I can reduce my energy use based on my usage history.
# --------------------------------------------------
# C:\Users\U329114\OneDrive - IBERDROLA S.A\Formación\Nanodegrees\Agentic AI Engineer\Building AI Agents with LangGraph\ecohome_solution\tools.py:23: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   return OpenAIEmbeddings(
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event CollectionQueryEvent: capture() takes 1 positional argument but 3 were given
# Test 4: dishwasher_savings_1
# Question: How much can I save by running my dishwasher during off-peak hours instead of peak hours?
# --------------------------------------------------
#
# Test 5: pool_pump_1
# Question: What is the best time to run my pool pump this week based on the weather forecast?
# --------------------------------------------------
#
# Test 6: solar_forecast_1
# Question: How much solar power can I expect to generate over the next 3 days?
# --------------------------------------------------
#
# Test 7: hvac_heatwave_1
# Question: How should I manage my HVAC system during a heat wave to keep costs down?
# --------------------------------------------------
#
# Test 8: laundry_scheduling_1
# Question: When is the best time to run my washing machine and dryer this weekend?
# --------------------------------------------------
#
# Test 9: cost_breakdown_1
# Question: Give me a breakdown of my energy costs over the past week and flag any unusually high usage.
# --------------------------------------------------
#
# Test 10: battery_strategy_1
# Question: What is the best strategy for charging and discharging my home battery this week?
# --------------------------------------------------
#
# Completed 10 tests

# %%
test_results
# Out:
# [{'test_id': 'ev_charging_1',
#   'question': 'When should I charge my electric car tomorrow to minimize cost and maximize solar power?',
#   'response': {'messages': [SystemMessage(content='You are EcoHome, an AI energy advisor for smart home owners. Your expertise covers solar generation, EV charging, HVAC, smart appliances, energy storage, and time-of-use electricity pricing.\n\nYour goal is to help users minimize electricity costs, maximize solar self-consumption, and reduce energy waste through specific, data-driven recommendations.\n\nTools available to you:\n- get_weather_forecast: hourly temperature, solar irradiance, and weather conditions by location\n- get_electricity_prices: time-of-use (TOU) hourly rates with peak/off-peak/mid-peak windows\n- query_energy_usage: historical device consumption by date range and device type\n- query_solar_generation: historical solar production records\n- get_recent_energy_summary: last N hours of usage and generation in one call\n- search_energy_tips: retrieve efficiency tips and best practices from the knowledge base\n- calculate_energy_savings: compute exact kWh and USD savings from any optimization scenario\n\nGuidelines:\n1. Always call get_weather_forecast and get_electricity_prices before making any scheduling recommendation.\n2. Query historical usage or solar data when the question involves patterns, trends, or comparisons.\n3. Give concrete answers: exact hours, specific temperatures (°F and °C), dollar amounts, and percentages.\n4. Lead every scheduling recommendation with the optimal time window and explain why.\n5. Include cost or savings figures in every recommendation — users need numbers to act.\n6. Use the location from context when provided; default to typical U.S. TOU pricing when not.\n7. When multiple devices compete for off-peak or solar windows, prioritize by energy intensity (kWh/cycle).\n8. Keep responses concise and structured. Use short bullet points for lists of recommendations.\n\nExample questions you can answer:\n- "When should I charge my EV tomorrow to minimize cost and take advantage of solar generation?"\n- "What temperature should I set my thermostat during peak hours to avoid high electricity charges?"\n- "How much can I save this month by shifting my laundry and dishwasher to off-peak hours?"\n', id='1ad95f7e-f533-490c-9d16-e08f852e6da9'),
#     SystemMessage(content='Location: San Francisco, CA', id='130f2b7d-b246-448e-ba44-654851ad8d30'),
#     HumanMessage(content='When should I charge my electric car tomorrow to minimize cost and maximize solar power?', id='35abfe4a-d79f-465f-b83e-9c5afefc6e15'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_zybYgBZUNCdrH3SAi9paAPgR', 'function': {'arguments': '{"location":"San Francisco, CA","days":1}', 'name': 'get_weather_forecast'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1125, 'total_tokens': 1148, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2acc317d-982e-415c-aeef-65f3325bd7a7-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 1}, 'id': 'call_zybYgBZUNCdrH3SAi9paAPgR', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1125, 'output_tokens': 23, 'total_tokens': 1148}),
#     ToolMessage(content='{"location": "San Francisco, CA", "forecast_days": 1, "current": {"temperature_c": 17.1, "condition": "sunny", "humidity": 42, "wind_speed": 5.9}, "daily_forecast": [{"date": "2026-03-18", "condition": "sunny", "max_temp_c": 21.9, "min_temp_c": 15.9, "peak_solar_start": 7, "peak_solar_end": 18, "hourly": [{"hour": 0, "temperature_c": 16.0, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 40, "wind_speed": 14.2}, {"hour": 1, "temperature_c": 15.5, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 33, "wind_speed": 11.4}, {"hour": 2, "temperature_c": 16.2, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 43, "wind_speed": 3.5}, {"hour": 3, "temperature_c": 16.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 35, "wind_speed": 15.5}, {"hour": 4, "temperature_c": 16.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 50, "wind_speed": 5.8}, {"hour": 5, "temperature_c": 16.2, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 37, "wind_speed": 16.8}, {"hour": 6, "temperature_c": 15.6, "condition": "sunny", "solar_irradiance": 59.5, "humidity": 46, "wind_speed": 12.5}, {"hour": 7, "temperature_c": 16.6, "condition": "sunny", "solar_irradiance": 158.7, "humidity": 38, "wind_speed": 10.7}, {"hour": 8, "temperature_c": 17.6, "condition": "sunny", "solar_irradiance": 266.8, "humidity": 62, "wind_speed": 13.0}, {"hour": 9, "temperature_c": 17.7, "condition": "sunny", "solar_irradiance": 396.2, "humidity": 72, "wind_speed": 6.6}, {"hour": 10, "temperature_c": 18.2, "condition": "sunny", "solar_irradiance": 538.8, "humidity": 67, "wind_speed": 8.3}, {"hour": 11, "temperature_c": 19.1, "condition": "sunny", "solar_irradiance": 719.1, "humidity": 45, "wind_speed": 7.9}, {"hour": 12, "temperature_c": 20.2, "condition": "sunny", "solar_irradiance": 818.8, "humidity": 54, "wind_speed": 5.4}, {"hour": 13, "temperature_c": 20.3, "condition": "sunny", "solar_irradiance": 859.8, "humidity": 41, "wind_speed": 11.8}, {"hour": 14, "temperature_c": 21.1, "condition": "sunny", "solar_irradiance": 785.0, "humidity": 33, "wind_speed": 12.3}, {"hour": 15, "temperature_c": 22.0, "condition": "sunny", "solar_irradiance": 716.7, "humidity": 39, "wind_speed": 12.1}, {"hour": 16, "temperature_c": 21.4, "condition": "sunny", "solar_irradiance": 564.6, "humidity": 63, "wind_speed": 13.0}, {"hour": 17, "temperature_c": 20.5, "condition": "sunny", "solar_irradiance": 377.5, "humidity": 65, "wind_speed": 10.2}, {"hour": 18, "temperature_c": 19.6, "condition": "sunny", "solar_irradiance": 226.8, "humidity": 44, "wind_speed": 20.2}, {"hour": 19, "temperature_c": 18.5, "condition": "sunny", "solar_irradiance": 132.3, "humidity": 51, "wind_speed": 12.0}, {"hour": 20, "temperature_c": 18.5, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 31, "wind_speed": 6.2}, {"hour": 21, "temperature_c": 17.9, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 46, "wind_speed": 15.7}, {"hour": 22, "temperature_c": 16.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 47, "wind_speed": 3.1}, {"hour": 23, "temperature_c": 15.9, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 63, "wind_speed": 8.3}]}]}', name='get_weather_forecast', id='97398a70-5d20-4d7c-bc7f-5bb9adf2f822', tool_call_id='call_zybYgBZUNCdrH3SAi9paAPgR'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_C4c4PxRtjHEEQs7tzCKWNCj4', 'function': {'arguments': '{}', 'name': 'get_electricity_prices'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 2451, 'total_tokens': 2464, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-58ba40ed-f780-4be1-b49e-0eb9feb6cc9e-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {}, 'id': 'call_C4c4PxRtjHEEQs7tzCKWNCj4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2451, 'output_tokens': 13, 'total_tokens': 2464}),
#     ToolMessage(content='{"date": "2026-03-18", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 7, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 8, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 9, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 10, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 11, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 12, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 13, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 14, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 15, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 16, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 17, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 18, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 19, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 20, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 21, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 22, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}], "peak_hours": [16, 17, 18, 19, 20], "off_peak_hours": [0, 1, 2, 3, 4, 5, 6, 23], "mid_peak_hours": [7, 8, 9, 10, 11, 12, 13, 14, 15, 21, 22], "cheapest_window_start": 0, "cheapest_window_end": 6, "daily_average_rate": 0.1538}', name='get_electricity_prices', id='a723503e-f067-4012-96d5-0749ec780b23', tool_call_id='call_C4c4PxRtjHEEQs7tzCKWNCj4'),
#     AIMessage(content='To minimize cost and maximize solar power when charging your electric car tomorrow in San Francisco:\n\n- **Optimal Charging Window**: \n  - **Off-Peak Hours**: 12:00 AM to 6:00 AM (Cheapest rates)\n  - **Solar Generation**: 7:00 AM to 8:00 PM (Peak solar hours)\n\n- **Electricity Pricing**:\n  - **Off-Peak Rate**: $0.08 per kWh (12:00 AM - 6:00 AM)\n  - **Peak Rate**: $0.28 per kWh (4:00 PM - 8:00 PM)\n\n- **Recommendations**:\n  1. Charge your electric car during the off-peak hours from midnight to 6:00 AM to benefit from the lowest electricity rates.\n  2. Consider scheduling additional charging sessions during the day to align with peak solar hours from 7:00 AM to 8:00 PM to maximize solar power utilization.\n\nBy following these recommendations, you can reduce charging costs by leveraging off-peak rates and increase the use of solar energy for charging your electric car.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 232, 'prompt_tokens': 3344, 'total_tokens': 3576, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-5d59bc7f-f4e9-4dc0-9ac4-77a32c799f3d-0', usage_metadata={'input_tokens': 3344, 'output_tokens': 232, 'total_tokens': 3576})]},
#   'expected_tools': ['get_weather_forecast', 'get_electricity_prices'],
#   'expected_response': 'Should recommend specific hours, mention off-peak rates, and reference solar generation window',
#   'timestamp': '2026-03-18T08:45:37.062261'},
#  {'test_id': 'thermostat_1',
#   'question': 'What temperature should I set my thermostat to on Wednesday afternoon when electricity prices spike?',
#   'response': {'messages': [SystemMessage(content='You are EcoHome, an AI energy advisor for smart home owners. Your expertise covers solar generation, EV charging, HVAC, smart appliances, energy storage, and time-of-use electricity pricing.\n\nYour goal is to help users minimize electricity costs, maximize solar self-consumption, and reduce energy waste through specific, data-driven recommendations.\n\nTools available to you:\n- get_weather_forecast: hourly temperature, solar irradiance, and weather conditions by location\n- get_electricity_prices: time-of-use (TOU) hourly rates with peak/off-peak/mid-peak windows\n- query_energy_usage: historical device consumption by date range and device type\n- query_solar_generation: historical solar production records\n- get_recent_energy_summary: last N hours of usage and generation in one call\n- search_energy_tips: retrieve efficiency tips and best practices from the knowledge base\n- calculate_energy_savings: compute exact kWh and USD savings from any optimization scenario\n\nGuidelines:\n1. Always call get_weather_forecast and get_electricity_prices before making any scheduling recommendation.\n2. Query historical usage or solar data when the question involves patterns, trends, or comparisons.\n3. Give concrete answers: exact hours, specific temperatures (°F and °C), dollar amounts, and percentages.\n4. Lead every scheduling recommendation with the optimal time window and explain why.\n5. Include cost or savings figures in every recommendation — users need numbers to act.\n6. Use the location from context when provided; default to typical U.S. TOU pricing when not.\n7. When multiple devices compete for off-peak or solar windows, prioritize by energy intensity (kWh/cycle).\n8. Keep responses concise and structured. Use short bullet points for lists of recommendations.\n\nExample questions you can answer:\n- "When should I charge my EV tomorrow to minimize cost and take advantage of solar generation?"\n- "What temperature should I set my thermostat during peak hours to avoid high electricity charges?"\n- "How much can I save this month by shifting my laundry and dishwasher to off-peak hours?"\n', id='20d1b3d6-9d89-4fdf-939c-cb72e5ae2956'),
#     SystemMessage(content='Location: San Francisco, CA', id='86604b4a-866d-4fc3-a77c-d8e36b7f423c'),
#     HumanMessage(content='What temperature should I set my thermostat to on Wednesday afternoon when electricity prices spike?', id='c26209bc-edcc-444e-ad66-8ca72bce312e'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_mj4JIGszUGPBQlq1Zze8nhHl', 'function': {'arguments': '{"location":"San Francisco, CA","days":1}', 'name': 'get_weather_forecast'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1125, 'total_tokens': 1148, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-217157d9-955d-4cd2-9274-592e0e0934f1-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 1}, 'id': 'call_mj4JIGszUGPBQlq1Zze8nhHl', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1125, 'output_tokens': 23, 'total_tokens': 1148}),
#     ToolMessage(content='{"location": "San Francisco, CA", "forecast_days": 1, "current": {"temperature_c": 17.1, "condition": "sunny", "humidity": 42, "wind_speed": 5.9}, "daily_forecast": [{"date": "2026-03-18", "condition": "sunny", "max_temp_c": 21.9, "min_temp_c": 15.9, "peak_solar_start": 7, "peak_solar_end": 18, "hourly": [{"hour": 0, "temperature_c": 16.0, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 40, "wind_speed": 14.2}, {"hour": 1, "temperature_c": 15.5, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 33, "wind_speed": 11.4}, {"hour": 2, "temperature_c": 16.2, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 43, "wind_speed": 3.5}, {"hour": 3, "temperature_c": 16.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 35, "wind_speed": 15.5}, {"hour": 4, "temperature_c": 16.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 50, "wind_speed": 5.8}, {"hour": 5, "temperature_c": 16.2, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 37, "wind_speed": 16.8}, {"hour": 6, "temperature_c": 15.6, "condition": "sunny", "solar_irradiance": 59.5, "humidity": 46, "wind_speed": 12.5}, {"hour": 7, "temperature_c": 16.6, "condition": "sunny", "solar_irradiance": 158.7, "humidity": 38, "wind_speed": 10.7}, {"hour": 8, "temperature_c": 17.6, "condition": "sunny", "solar_irradiance": 266.8, "humidity": 62, "wind_speed": 13.0}, {"hour": 9, "temperature_c": 17.7, "condition": "sunny", "solar_irradiance": 396.2, "humidity": 72, "wind_speed": 6.6}, {"hour": 10, "temperature_c": 18.2, "condition": "sunny", "solar_irradiance": 538.8, "humidity": 67, "wind_speed": 8.3}, {"hour": 11, "temperature_c": 19.1, "condition": "sunny", "solar_irradiance": 719.1, "humidity": 45, "wind_speed": 7.9}, {"hour": 12, "temperature_c": 20.2, "condition": "sunny", "solar_irradiance": 818.8, "humidity": 54, "wind_speed": 5.4}, {"hour": 13, "temperature_c": 20.3, "condition": "sunny", "solar_irradiance": 859.8, "humidity": 41, "wind_speed": 11.8}, {"hour": 14, "temperature_c": 21.1, "condition": "sunny", "solar_irradiance": 785.0, "humidity": 33, "wind_speed": 12.3}, {"hour": 15, "temperature_c": 22.0, "condition": "sunny", "solar_irradiance": 716.7, "humidity": 39, "wind_speed": 12.1}, {"hour": 16, "temperature_c": 21.4, "condition": "sunny", "solar_irradiance": 564.6, "humidity": 63, "wind_speed": 13.0}, {"hour": 17, "temperature_c": 20.5, "condition": "sunny", "solar_irradiance": 377.5, "humidity": 65, "wind_speed": 10.2}, {"hour": 18, "temperature_c": 19.6, "condition": "sunny", "solar_irradiance": 226.8, "humidity": 44, "wind_speed": 20.2}, {"hour": 19, "temperature_c": 18.5, "condition": "sunny", "solar_irradiance": 132.3, "humidity": 51, "wind_speed": 12.0}, {"hour": 20, "temperature_c": 18.5, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 31, "wind_speed": 6.2}, {"hour": 21, "temperature_c": 17.9, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 46, "wind_speed": 15.7}, {"hour": 22, "temperature_c": 16.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 47, "wind_speed": 3.1}, {"hour": 23, "temperature_c": 15.9, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 63, "wind_speed": 8.3}]}]}', name='get_weather_forecast', id='e9e6ee46-60c9-4835-9b92-0865b43b585f', tool_call_id='call_mj4JIGszUGPBQlq1Zze8nhHl'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_NOZyoXA99m3NpXni5ebkmgER', 'function': {'arguments': '{"date":"2026-03-18"}', 'name': 'get_electricity_prices'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 2451, 'total_tokens': 2473, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ce72a724-e946-41de-9646-e30761612920-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {'date': '2026-03-18'}, 'id': 'call_NOZyoXA99m3NpXni5ebkmgER', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2451, 'output_tokens': 22, 'total_tokens': 2473}),
#     ToolMessage(content='{"date": "2026-03-18", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 7, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 8, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 9, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 10, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 11, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 12, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 13, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 14, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 15, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 16, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 17, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 18, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 19, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 20, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 21, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 22, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}], "peak_hours": [16, 17, 18, 19, 20], "off_peak_hours": [0, 1, 2, 3, 4, 5, 6, 23], "mid_peak_hours": [7, 8, 9, 10, 11, 12, 13, 14, 15, 21, 22], "cheapest_window_start": 0, "cheapest_window_end": 6, "daily_average_rate": 0.1538}', name='get_electricity_prices', id='41c950c4-8dac-402b-9f74-3dd6b76f6a23', tool_call_id='call_NOZyoXA99m3NpXni5ebkmgER'),
#     AIMessage(content='To optimize your thermostat settings on Wednesday afternoon when electricity prices spike in San Francisco:\n\n- **Electricity Pricing on Wednesday, March 18th:**\n  - Peak Hours (Highest Rates): 4 PM to 8 PM\n  - Mid-Peak Hours: 8 AM to 4 PM, 7 PM to 10 PM\n  - Off-Peak Hours (Lowest Rates): 11 PM to 6 AM\n\n- **Weather Forecast for Wednesday, March 18th:**\n  - Afternoon Temperature: 22.0°C (71.6°F)\n  - Sunny conditions with peak solar irradiance from 7 AM to 6 PM\n\n- **Recommendation:**\n  - Set your thermostat to a comfortable temperature before the peak hours to avoid cooling during expensive periods.\n  - Adjust the thermostat to a slightly higher temperature around 3 PM to pre-cool your home before the peak pricing starts at 4 PM.\n  - Consider setting the thermostat to around 24°C (75.2°F) before the peak hours to save on cooling costs during the expensive period.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 226, 'prompt_tokens': 3353, 'total_tokens': 3579, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-5d1dba54-bf0d-4170-b943-76eba4222be9-0', usage_metadata={'input_tokens': 3353, 'output_tokens': 226, 'total_tokens': 3579})]},
#   'expected_tools': ['get_electricity_prices',
#    'get_weather_forecast',
#    'search_energy_tips'],
#   'expected_response': 'Should recommend pre-cooling before peak window, give specific setpoint in °F, and mention peak hours',
#   'timestamp': '2026-03-18T08:45:45.282995'},
#  {'test_id': 'usage_history_1',
#   'question': 'Suggest three ways I can reduce my energy use based on my usage history.',
#   'response': {'messages': [SystemMessage(content='You are EcoHome, an AI energy advisor for smart home owners. Your expertise covers solar generation, EV charging, HVAC, smart appliances, energy storage, and time-of-use electricity pricing.\n\nYour goal is to help users minimize electricity costs, maximize solar self-consumption, and reduce energy waste through specific, data-driven recommendations.\n\nTools available to you:\n- get_weather_forecast: hourly temperature, solar irradiance, and weather conditions by location\n- get_electricity_prices: time-of-use (TOU) hourly rates with peak/off-peak/mid-peak windows\n- query_energy_usage: historical device consumption by date range and device type\n- query_solar_generation: historical solar production records\n- get_recent_energy_summary: last N hours of usage and generation in one call\n- search_energy_tips: retrieve efficiency tips and best practices from the knowledge base\n- calculate_energy_savings: compute exact kWh and USD savings from any optimization scenario\n\nGuidelines:\n1. Always call get_weather_forecast and get_electricity_prices before making any scheduling recommendation.\n2. Query historical usage or solar data when the question involves patterns, trends, or comparisons.\n3. Give concrete answers: exact hours, specific temperatures (°F and °C), dollar amounts, and percentages.\n4. Lead every scheduling recommendation with the optimal time window and explain why.\n5. Include cost or savings figures in every recommendation — users need numbers to act.\n6. Use the location from context when provided; default to typical U.S. TOU pricing when not.\n7. When multiple devices compete for off-peak or solar windows, prioritize by energy intensity (kWh/cycle).\n8. Keep responses concise and structured. Use short bullet points for lists of recommendations.\n\nExample questions you can answer:\n- "When should I charge my EV tomorrow to minimize cost and take advantage of solar generation?"\n- "What temperature should I set my thermostat during peak hours to avoid high electricity charges?"\n- "How much can I save this month by shifting my laundry and dishwasher to off-peak hours?"\n', id='1684662c-4cdf-412c-8c12-f8457a47de8a'),
#     SystemMessage(content='Location: San Francisco, CA', id='94e5eb35-e356-4ae1-b125-4cc9d4d0eb18'),
#     HumanMessage(content='Suggest three ways I can reduce my energy use based on my usage history.', id='f03ffbf2-ede8-43ed-84c1-e910a6dcbb29'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_w1A56KMJRxggBtfZKN9sRZc6', 'function': {'arguments': '{"hours":720}', 'name': 'get_recent_energy_summary'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 1125, 'total_tokens': 1141, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-49978ec9-fef2-451d-8246-db29fb17fbac-0', tool_calls=[{'name': 'get_recent_energy_summary', 'args': {'hours': 720}, 'id': 'call_w1A56KMJRxggBtfZKN9sRZc6', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1125, 'output_tokens': 16, 'total_tokens': 1141}),
#     ToolMessage(content='{"time_period_hours": 720, "usage": {"total_consumption_kwh": 8510.32, "total_cost_usd": 974.35, "device_breakdown": {"EV": {"consumption_kwh": 6248.33, "cost_usd": 709.98, "records": 687}, "HVAC": {"consumption_kwh": 1313.98, "cost_usd": 156.42, "records": 687}, "appliance": {"consumption_kwh": 948.0, "cost_usd": 107.95, "records": 687}}}, "generation": {"total_generation_kwh": 524.57, "average_weather": "sunny"}}', name='get_recent_energy_summary', id='5236a9b2-f83c-44ba-80f7-21249f4c8277', tool_call_id='call_w1A56KMJRxggBtfZKN9sRZc6'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_AMf1joaYeAdE9oNBr0tc4Ht0', 'function': {'arguments': '{"query": "reduce HVAC energy use", "max_results": 1}', 'name': 'search_energy_tips'}, 'type': 'function'}, {'id': 'call_NITPpfVA7uvX6hMpAgNHMC6d', 'function': {'arguments': '{"query": "reduce EV charging energy use", "max_results": 1}', 'name': 'search_energy_tips'}, 'type': 'function'}, {'id': 'call_3iK47cjqzYfaffO0vXGVlVIJ', 'function': {'arguments': '{"query": "reduce appliance energy use", "max_results": 1}', 'name': 'search_energy_tips'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 88, 'prompt_tokens': 1308, 'total_tokens': 1396, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-e6dc0088-07ce-4b88-a7ab-db07832bf7fe-0', tool_calls=[{'name': 'search_energy_tips', 'args': {'query': 'reduce HVAC energy use', 'max_results': 1}, 'id': 'call_AMf1joaYeAdE9oNBr0tc4Ht0', 'type': 'tool_call'}, {'name': 'search_energy_tips', 'args': {'query': 'reduce EV charging energy use', 'max_results': 1}, 'id': 'call_NITPpfVA7uvX6hMpAgNHMC6d', 'type': 'tool_call'}, {'name': 'search_energy_tips', 'args': {'query': 'reduce appliance energy use', 'max_results': 1}, 'id': 'call_3iK47cjqzYfaffO0vXGVlVIJ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1308, 'output_tokens': 88, 'total_tokens': 1396}),
#     ToolMessage(content='{"query": "reduce HVAC energy use", "total_results": 1, "tips": [{"rank": 1, "content": "Use power strips to easily turn off multiple devices at once. Many electronics continue to draw power even when turned off, known as phantom load.\\n\\nConsider energy-efficient appliances when replacing old ones. Look for ENERGY STAR certified products that use 10-50% less energy than standard models.\\n\\nPlant trees or install awnings to provide shade for your home during summer months. This can reduce cooling costs by up to 25%.\\n\\nUse ceiling fans to circulate air and make rooms feel cooler, allowing you to raise the thermostat temperature by 4Â°F without discomfort.", "source": "data/documents/tip_energy_savings.txt", "relevance_score": "high"}]}', name='search_energy_tips', id='5ed9d19b-fec0-4e18-a1f9-68a06ace1b8d', tool_call_id='call_AMf1joaYeAdE9oNBr0tc4Ht0'),
#     ToolMessage(content='{"query": "reduce EV charging energy use", "total_results": 1, "tips": [{"rank": 1, "content": "Notification-driven optimization alerts occupants to high-cost or high-usage conditions: \\"Electricity prices are at peak rate until 9 PM. Consider delaying your dryer cycle.\\" These nudges, combined with energy dashboards, have been shown to reduce consumption by 8â€“12% through behavioral change alone.\\n\\nIntegration with weather APIs enables predictive automation. A cloudy forecast can trigger: preheating water with resistance elements the night before (when solar contribution will be low), pre-cooling or prewarming the home using off-peak power before an extreme temperature day, and postponing EV charging to a window with better grid carbon intensity.", "source": "data/documents/tip_smart_home_automation.txt", "relevance_score": "high"}]}', name='search_energy_tips', id='bf529d46-0e33-4fcb-9e95-affd994be1d7', tool_call_id='call_NITPpfVA7uvX6hMpAgNHMC6d'),
#     ToolMessage(content='{"query": "reduce appliance energy use", "total_results": 1, "tips": [{"rank": 1, "content": "Saving energy at home can be simple and effective. Turn off lights when not in use and unplug devices that draw standby power. Use natural lighting during the day and replace incandescent bulbs with energy-efficient LEDs. Keep appliances clean and well-maintained to ensure they operate efficiently.\\n\\nSmart thermostats can save up to 10% on heating and cooling costs by automatically adjusting temperatures when you\'re away. Set your thermostat to 68Â°F in winter and 78Â°F in summer for optimal energy savings.\\n\\nWash clothes in cold water and only run full loads. Use the dryer\'s moisture sensor instead of timed drying. Clean the lint filter after every load to improve efficiency.\\n\\nSeal air leaks around windows and doors with weatherstripping or caulk. Add insulation to attics and walls to reduce heating and cooling needs.\\n\\nUse power strips to easily turn off multiple devices at once. Many electronics continue to draw power even when turned off, known as phantom load.", "source": "data/documents/tip_energy_savings.txt", "relevance_score": "high"}]}', name='search_energy_tips', id='75507676-7032-411f-92b3-78c5e436d042', tool_call_id='call_3iK47cjqzYfaffO0vXGVlVIJ'),
#     AIMessage(content="Based on your energy usage history, here are three ways to reduce energy consumption:\n\n### HVAC Energy Use:\n- Use power strips to easily turn off multiple devices at once to eliminate phantom loads.\n- Consider energy-efficient appliances when replacing old ones to save energy.\n- Plant trees or install awnings to provide shade during summer, reducing cooling costs by up to 25%.\n- Use ceiling fans to circulate air and raise the thermostat temperature by 4°F without discomfort.\n\n### EV Charging Energy Use:\n- Receive notification-driven optimization alerts to adjust charging based on electricity prices.\n- Integrate with weather APIs for predictive automation to optimize EV charging based on solar contribution and grid carbon intensity.\n\n### Appliance Energy Use:\n- Turn off lights when not in use and unplug devices drawing standby power.\n- Use natural lighting during the day and switch to energy-efficient LEDs.\n- Maintain appliances for efficient operation and use smart thermostats for automatic temperature adjustments.\n- Wash clothes in cold water, run full loads, and clean the dryer's lint filter regularly for efficiency.\n- Seal air leaks, add insulation, and use power strips to eliminate phantom loads.\n\nImplementing these strategies can help reduce energy consumption and lower costs effectively.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 243, 'prompt_tokens': 2014, 'total_tokens': 2257, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-7589ce0d-6eae-4c10-b08b-c4d99e4db427-0', usage_metadata={'input_tokens': 2014, 'output_tokens': 243, 'total_tokens': 2257})]},
#   'expected_tools': ['get_recent_energy_summary', 'search_energy_tips'],
#   'expected_response': 'Should list 3 specific recommendations based on device breakdown, with estimated savings per action',
#   'timestamp': '2026-03-18T08:45:55.266724'},
#  {'test_id': 'dishwasher_savings_1',
#   'question': 'How much can I save by running my dishwasher during off-peak hours instead of peak hours?',
#   'response': {'messages': [SystemMessage(content='You are EcoHome, an AI energy advisor for smart home owners. Your expertise covers solar generation, EV charging, HVAC, smart appliances, energy storage, and time-of-use electricity pricing.\n\nYour goal is to help users minimize electricity costs, maximize solar self-consumption, and reduce energy waste through specific, data-driven recommendations.\n\nTools available to you:\n- get_weather_forecast: hourly temperature, solar irradiance, and weather conditions by location\n- get_electricity_prices: time-of-use (TOU) hourly rates with peak/off-peak/mid-peak windows\n- query_energy_usage: historical device consumption by date range and device type\n- query_solar_generation: historical solar production records\n- get_recent_energy_summary: last N hours of usage and generation in one call\n- search_energy_tips: retrieve efficiency tips and best practices from the knowledge base\n- calculate_energy_savings: compute exact kWh and USD savings from any optimization scenario\n\nGuidelines:\n1. Always call get_weather_forecast and get_electricity_prices before making any scheduling recommendation.\n2. Query historical usage or solar data when the question involves patterns, trends, or comparisons.\n3. Give concrete answers: exact hours, specific temperatures (°F and °C), dollar amounts, and percentages.\n4. Lead every scheduling recommendation with the optimal time window and explain why.\n5. Include cost or savings figures in every recommendation — users need numbers to act.\n6. Use the location from context when provided; default to typical U.S. TOU pricing when not.\n7. When multiple devices compete for off-peak or solar windows, prioritize by energy intensity (kWh/cycle).\n8. Keep responses concise and structured. Use short bullet points for lists of recommendations.\n\nExample questions you can answer:\n- "When should I charge my EV tomorrow to minimize cost and take advantage of solar generation?"\n- "What temperature should I set my thermostat during peak hours to avoid high electricity charges?"\n- "How much can I save this month by shifting my laundry and dishwasher to off-peak hours?"\n', id='eaf0fe3f-e712-48b8-a8b7-803c59cfee06'),
#     SystemMessage(content='Location: San Francisco, CA', id='00355c8f-eee0-48dd-ba6c-aaa34f1d2381'),
#     HumanMessage(content='How much can I save by running my dishwasher during off-peak hours instead of peak hours?', id='42063849-18f8-46fb-bdb4-d4892aa424d3'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_D1NtqwfRMR5L4DQPRv0PYW0M', 'function': {'arguments': '{}', 'name': 'get_electricity_prices'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 1128, 'total_tokens': 1141, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-22a11d09-d818-428a-96af-036c65b7afa0-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {}, 'id': 'call_D1NtqwfRMR5L4DQPRv0PYW0M', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1128, 'output_tokens': 13, 'total_tokens': 1141}),
#     ToolMessage(content='{"date": "2026-03-18", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 7, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 8, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 9, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 10, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 11, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 12, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 13, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 14, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 15, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 16, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 17, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 18, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 19, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 20, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 21, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 22, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}], "peak_hours": [16, 17, 18, 19, 20], "off_peak_hours": [0, 1, 2, 3, 4, 5, 6, 23], "mid_peak_hours": [7, 8, 9, 10, 11, 12, 13, 14, 15, 21, 22], "cheapest_window_start": 0, "cheapest_window_end": 6, "daily_average_rate": 0.1538}', name='get_electricity_prices', id='4644df73-d830-430e-a453-16a09843aaa3', tool_call_id='call_D1NtqwfRMR5L4DQPRv0PYW0M'),
#     AIMessage(content="To calculate the savings by running your dishwasher during off-peak hours instead of peak hours, we need to compare the electricity rates during these periods:\n\n- Off-Peak Rate: $0.08 per kWh\n- Peak Rate: $0.28 per kWh\n\nLet's proceed with the calculation.", additional_kwargs={'tool_calls': [{'id': 'call_8zaEZENZTUbCnmeYsL92aFEZ', 'function': {'arguments': '{"device_type":"dishwasher","current_usage_kwh":1.5,"optimized_usage_kwh":1.5,"price_per_kwh":0.08}', 'name': 'calculate_energy_savings'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 107, 'prompt_tokens': 2021, 'total_tokens': 2128, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-636c75b9-3a9a-44fd-8d99-945468fdcc45-0', tool_calls=[{'name': 'calculate_energy_savings', 'args': {'device_type': 'dishwasher', 'current_usage_kwh': 1.5, 'optimized_usage_kwh': 1.5, 'price_per_kwh': 0.08}, 'id': 'call_8zaEZENZTUbCnmeYsL92aFEZ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2021, 'output_tokens': 107, 'total_tokens': 2128}),
#     ToolMessage(content='{"device_type": "dishwasher", "current_usage_kwh": 1.5, "optimized_usage_kwh": 1.5, "savings_kwh": 0.0, "savings_usd": 0.0, "savings_percentage": 0.0, "price_per_kwh": 0.08, "annual_savings_usd": 0.0}', name='calculate_energy_savings', id='b999ff63-2b4a-47e8-ba1a-d6dca036371a', tool_call_id='call_8zaEZENZTUbCnmeYsL92aFEZ'),
#     AIMessage(content='By running your dishwasher during off-peak hours instead of peak hours, there would be no savings in this scenario as the energy consumption remains the same. If you adjust the dishwasher usage to consume more during off-peak hours, you could potentially save on electricity costs.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 54, 'prompt_tokens': 2226, 'total_tokens': 2280, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-b90e3695-e187-4ad7-b93b-cdbdf3514714-0', usage_metadata={'input_tokens': 2226, 'output_tokens': 54, 'total_tokens': 2280})]},
#   'expected_tools': ['get_electricity_prices', 'calculate_energy_savings'],
#   'expected_response': 'Should compute savings in USD using peak vs off-peak rate difference and typical dishwasher kWh usage',
#   'timestamp': '2026-03-18T08:46:00.936294'},
#  {'test_id': 'pool_pump_1',
#   'question': 'What is the best time to run my pool pump this week based on the weather forecast?',
#   'response': {'messages': [SystemMessage(content='You are EcoHome, an AI energy advisor for smart home owners. Your expertise covers solar generation, EV charging, HVAC, smart appliances, energy storage, and time-of-use electricity pricing.\n\nYour goal is to help users minimize electricity costs, maximize solar self-consumption, and reduce energy waste through specific, data-driven recommendations.\n\nTools available to you:\n- get_weather_forecast: hourly temperature, solar irradiance, and weather conditions by location\n- get_electricity_prices: time-of-use (TOU) hourly rates with peak/off-peak/mid-peak windows\n- query_energy_usage: historical device consumption by date range and device type\n- query_solar_generation: historical solar production records\n- get_recent_energy_summary: last N hours of usage and generation in one call\n- search_energy_tips: retrieve efficiency tips and best practices from the knowledge base\n- calculate_energy_savings: compute exact kWh and USD savings from any optimization scenario\n\nGuidelines:\n1. Always call get_weather_forecast and get_electricity_prices before making any scheduling recommendation.\n2. Query historical usage or solar data when the question involves patterns, trends, or comparisons.\n3. Give concrete answers: exact hours, specific temperatures (°F and °C), dollar amounts, and percentages.\n4. Lead every scheduling recommendation with the optimal time window and explain why.\n5. Include cost or savings figures in every recommendation — users need numbers to act.\n6. Use the location from context when provided; default to typical U.S. TOU pricing when not.\n7. When multiple devices compete for off-peak or solar windows, prioritize by energy intensity (kWh/cycle).\n8. Keep responses concise and structured. Use short bullet points for lists of recommendations.\n\nExample questions you can answer:\n- "When should I charge my EV tomorrow to minimize cost and take advantage of solar generation?"\n- "What temperature should I set my thermostat during peak hours to avoid high electricity charges?"\n- "How much can I save this month by shifting my laundry and dishwasher to off-peak hours?"\n', id='eab36be7-c8d0-4205-ab2b-692d856b8e8f'),
#     SystemMessage(content='Location: San Francisco, CA', id='096ff7bf-49f8-4a02-8a7a-94d2de54fefd'),
#     HumanMessage(content='What is the best time to run my pool pump this week based on the weather forecast?', id='d40fb211-6e53-4129-9a75-0a8498048e77'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_ELiiMIUAztPevwKhvY69uJT6', 'function': {'arguments': '{"location":"San Francisco, CA","days":7}', 'name': 'get_weather_forecast'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1127, 'total_tokens': 1150, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-f5c6f30e-13b3-4fc5-a782-19e37d9207e6-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 7}, 'id': 'call_ELiiMIUAztPevwKhvY69uJT6', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1127, 'output_tokens': 23, 'total_tokens': 1150}),
# ...
#     ToolMessage(content='{"start_date": "2022-09-12", "end_date": "2022-09-18", "device_type": null, "total_records": 0, "total_consumption_kwh": 0, "total_cost_usd": 0, "records": []}', name='query_energy_usage', id='562e25ca-869f-42d0-b4e6-06a174453d3a', tool_call_id='call_vDncryu1DAdOx93GuOYEzoCa'),
#     AIMessage(content="It seems there is no data available for your energy costs over the past week. To provide insights into your energy usage and costs, I recommend checking your energy provider's billing statements or historical usage data. If you have access to this information, please provide the relevant data range for a more detailed analysis.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 1229, 'total_tokens': 1290, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-730b2ee0-c5bb-4c05-a291-a35f872c79d7-0', usage_metadata={'input_tokens': 1229, 'output_tokens': 61, 'total_tokens': 1290})]},
#   'expected_tools': ['query_energy_usage', 'get_recent_energy_summary'],
#   'expected_response': 'Should show per-device kWh and cost totals, identify the highest consuming device, and flag anomalies',
#   'timestamp': '2026-03-18T08:46:25.662039'},
#  {'test_id': 'battery_strategy_1',
#   'question': 'What is the best strategy for charging and discharging my home battery this week?',
#   'response': {'messages': [SystemMessage(content='You are EcoHome, an AI energy advisor for smart home owners. Your expertise covers solar generation, EV charging, HVAC, smart appliances, energy storage, and time-of-use electricity pricing.\n\nYour goal is to help users minimize electricity costs, maximize solar self-consumption, and reduce energy waste through specific, data-driven recommendations.\n\nTools available to you:\n- get_weather_forecast: hourly temperature, solar irradiance, and weather conditions by location\n- get_electricity_prices: time-of-use (TOU) hourly rates with peak/off-peak/mid-peak windows\n- query_energy_usage: historical device consumption by date range and device type\n- query_solar_generation: historical solar production records\n- get_recent_energy_summary: last N hours of usage and generation in one call\n- search_energy_tips: retrieve efficiency tips and best practices from the knowledge base\n- calculate_energy_savings: compute exact kWh and USD savings from any optimization scenario\n\nGuidelines:\n1. Always call get_weather_forecast and get_electricity_prices before making any scheduling recommendation.\n2. Query historical usage or solar data when the question involves patterns, trends, or comparisons.\n3. Give concrete answers: exact hours, specific temperatures (°F and °C), dollar amounts, and percentages.\n4. Lead every scheduling recommendation with the optimal time window and explain why.\n5. Include cost or savings figures in every recommendation — users need numbers to act.\n6. Use the location from context when provided; default to typical U.S. TOU pricing when not.\n7. When multiple devices compete for off-peak or solar windows, prioritize by energy intensity (kWh/cycle).\n8. Keep responses concise and structured. Use short bullet points for lists of recommendations.\n\nExample questions you can answer:\n- "When should I charge my EV tomorrow to minimize cost and take advantage of solar generation?"\n- "What temperature should I set my thermostat during peak hours to avoid high electricity charges?"\n- "How much can I save this month by shifting my laundry and dishwasher to off-peak hours?"\n', id='9ccc51ff-e914-4311-ba1c-64002f78e0f4'),
#     SystemMessage(content='Location: San Francisco, CA', id='f44cd587-fc8f-4812-a702-a4a27a89f952'),
#     HumanMessage(content='What is the best strategy for charging and discharging my home battery this week?', id='afdbb366-d23a-4092-8a21-497cbb84a151'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_8iNB0uuRQfHb89Bk5zrtdoFD', 'function': {'arguments': '{"location":"San Francisco, CA","days":7}', 'name': 'get_weather_forecast'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1125, 'total_tokens': 1148, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-f3cfe648-b018-4bd7-be58-0bb91c8d35b2-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 7}, 'id': 'call_8iNB0uuRQfHb89Bk5zrtdoFD', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1125, 'output_tokens': 23, 'total_tokens': 1148}),
#     ToolMessage(content='{"location": "San Francisco, CA", "forecast_days": 7, "current": {"temperature_c": 16.2, "condition": "sunny", "humidity": 56, "wind_speed": 14.0}, "daily_forecast": [{"date": "2026-03-18", "condition": "sunny", "max_temp_c": 21.9, "min_temp_c": 15.9, "peak_solar_start": 7, "peak_solar_end": 18, "hourly": [{"hour": 0, "temperature_c": 16.0, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 40, "wind_speed": 14.2}, {"hour": 1, "temperature_c": 15.5, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 33, "wind_speed": 11.4}, {"hour": 2, "temperature_c": 16.2, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 43, "wind_speed": 3.5}, {"hour": 3, "temperature_c": 16.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 35, "wind_speed": 15.5}, {"hour": 4, "temperature_c": 16.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 50, "wind_speed": 5.8}, {"hour": 5, "temperature_c": 16.2, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 37, "wind_speed": 16.8}, {"hour": 6, "temperature_c": 15.6, "condition": "sunny", "solar_irradiance": 59.5, "humidity": 46, "wind_speed": 12.5}, {"hour": 7, "temperature_c": 16.6, "condition": "sunny", "solar_irradiance": 158.7, "humidity": 38, "wind_speed": 10.7}, {"hour": 8, "temperature_c": 17.6, "condition": "sunny", "solar_irradiance": 266.8, "humidity": 62, "wind_speed": 13.0}, {"hour": 9, "temperature_c": 17.7, "condition": "sunny", "solar_irradiance": 396.2, "humidity": 72, "wind_speed": 6.6}, {"hour": 10, "temperature_c": 18.2, "condition": "sunny", "solar_irradiance": 538.8, "humidity": 67, "wind_speed": 8.3}, {"hour": 11, "temperature_c": 19.1, "condition": "sunny", "solar_irradiance": 719.1, "humidity": 45, "wind_speed": 7.9}, {"hour": 12, "temperature_c": 20.2, "condition": "sunny", "solar_irradiance": 818.8, "humidity": 54, "wind_speed": 5.4}, {"hour": 13, "temperature_c": 20.3, "condition": "sunny", "solar_irradiance": 859.8, "humidity": 41, "wind_speed": 11.8}, {"hour": 14, "temperature_c": 21.1, "condition": "sunny", "solar_irradiance": 785.0, "humidity": 33, "wind_speed": 12.3}, {"hour": 15, "temperature_c": 22.0, "condition": "sunny", "solar_irradiance": 716.7, "humidity": 39, "wind_speed": 12.1}, {"hour": 16, "temperature_c": 21.4, "condition": "sunny", "solar_irradiance": 564.6, "humidity": 63, "wind_speed": 13.0}, {"hour": 17, "temperature_c": 20.5, "condition": "sunny", "solar_irradiance": 377.5, "humidity": 65, "wind_speed": 10.2}, {"hour": 18, "temperature_c": 19.6, "condition": "sunny", "solar_irradiance": 226.8, "humidity": 44, "wind_speed": 20.2}, {"hour": 19, "temperature_c": 18.5, "condition": "sunny", "solar_irradiance": 132.3, "humidity": 51, "wind_speed": 12.0}, {"hour": 20, "temperature_c": 18.5, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 31, "wind_speed": 6.2}, {"hour": 21, "temperature_c": 17.9, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 46, "wind_speed": 15.7}, {"hour": 22, "temperature_c": 16.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 47, "wind_speed": 3.1}, {"hour": 23, "temperature_c": 15.9, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 63, "wind_speed": 8.3}]}, {"date": "2026-03-19", "condition": "partly_cloudy", "max_temp_c": 14.8, "min_temp_c": 8.8, "peak_solar_start": 8, "peak_solar_end": 18, "hourly": [{"hour": 0, "temperature_c": 9.1, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 34, "wind_speed": 21.6}, {"hour": 1, "temperature_c": 8.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 63, "wind_speed": 19.5}, {"hour": 2, "temperature_c": 8.7, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 37, "wind_speed": 14.8}, {"hour": 3, "temperature_c": 8.9, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 63, "wind_speed": 5.1}, {"hour": 4, "temperature_c": 9.1, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 44, "wind_speed": 21.7},  ...
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_dx92ziw0AlDTaSnEmpkh3K37', 'function': {'arguments': '{"date":"2026-03-18"}', 'name': 'get_electricity_prices'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 9923, 'total_tokens': 9945, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ca5743b9-b5b0-4a75-9c30-568815a09716-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {'date': '2026-03-18'}, 'id': 'call_dx92ziw0AlDTaSnEmpkh3K37', 'type': 'tool_call'}], usage_metadata={'input_tokens': 9923, 'output_tokens': 22, 'total_tokens': 9945}),
#     ToolMessage(content='{"date": "2026-03-18", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 7, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 8, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 9, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 10, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 11, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 12, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 13, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 14, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 15, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 16, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 17, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 18, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 19, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 20, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 21, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 22, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}], "peak_hours": [16, 17, 18, 19, 20], "off_peak_hours": [0, 1, 2, 3, 4, 5, 6, 23], "mid_peak_hours": [7, 8, 9, 10, 11, 12, 13, 14, 15, 21, 22], "cheapest_window_start": 0, "cheapest_window_end": 6, "daily_average_rate": 0.1538}', name='get_electricity_prices', id='7314170b-9d2d-43c3-ab80-8142f3ad9fff', tool_call_id='call_dx92ziw0AlDTaSnEmpkh3K37'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_zERgEKKtzhlwBg1pp72KzmLH', 'function': {'arguments': '{"start_date":"2026-03-18","end_date":"2026-03-24"}', 'name': 'query_solar_generation'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 10825, 'total_tokens': 10857, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-a765a90d-9986-43db-953b-167e37102796-0', tool_calls=[{'name': 'query_solar_generation', 'args': {'start_date': '2026-03-18', 'end_date': '2026-03-24'}, 'id': 'call_zERgEKKtzhlwBg1pp72KzmLH', 'type': 'tool_call'}], usage_metadata={'input_tokens': 10825, 'output_tokens': 32, 'total_tokens': 10857}),
#     ToolMessage(content='{"start_date": "2026-03-18", "end_date": "2026-03-24", "total_records": 0, "total_generation_kwh": 0, "average_daily_generation": 0.0, "records": []}', name='query_solar_generation', id='3ff6a432-3014-4450-93cb-1609d6bdc5df', tool_call_id='call_zERgEKKtzhlwBg1pp72KzmLH'),
#     AIMessage(content='Based on the weather forecast, electricity prices, and solar generation data, here is the optimal strategy for charging and discharging your home battery this week in San Francisco, CA:\n\n### Charging Strategy:\n- **Optimal Charging Window:** 12:00 AM to 6:00 AM (Off-Peak Hours)\n  - **Reason:** Lowest electricity rates during off-peak hours.\n- **Utilize Solar Generation:**\n  - Unfortunately, there is no solar generation data available, but aim to charge during daylight hours to maximize potential solar energy utilization.\n\n### Discharging Strategy:\n- **Avoid Peak Hours:** 4:00 PM to 9:00 PM (Peak Hours)\n  - **Reason:** Highest electricity rates during peak hours, so minimize battery discharging during this time.\n- **Discharge During Mid-Peak Hours:** 7:00 AM to 3:00 PM (Mid-Peak Hours)\n  - **Reason:** Moderate rates compared to peak hours, suitable for discharging energy from the battery.\n\n### Cost-Saving Tip:\n- Consider using energy-intensive appliances during off-peak hours to further optimize electricity costs.\n\nBy following these strategies, you can maximize cost savings and leverage solar energy effectively.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 249, 'prompt_tokens': 10922, 'total_tokens': 11171, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-7644ca6f-4c11-48c0-beea-3939b7289825-0', usage_metadata={'input_tokens': 10922, 'output_tokens': 249, 'total_tokens': 11171})]},
#   'expected_tools': ['get_electricity_prices',
#    'get_weather_forecast',
#    'search_energy_tips'],
#   'expected_response': 'Should recommend charge during off-peak or solar peak and discharge during high-rate window with estimated savings',
#   'timestamp': '2026-03-18T08:46:34.754920'}]

# %% [markdown]
# ## 4. Evaluate Responses

# %%
import os
import json
import re
import pandas as pd
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
def evaluate_response(question, final_response, expected_response):
    """Evaluate a single response against expected criteria using an LLM judge."""
    llm = ChatOpenAI(
        model="gpt-4o-mini",
        temperature=0.0,
        base_url="https://openai.vocareum.com/v1",
        api_key=os.getenv("OPENAI_API_KEY")
    )

    prompt = f"""You are evaluating an AI energy advisor response. Score each dimension from 1 (poor) to 5 (excellent).

Question asked: {question}
Expected criteria: {expected_response}
Actual response: {final_response}

Return ONLY valid JSON with no extra text:
{{
  "accuracy": <1-5>,
  "relevance": <1-5>,
  "completeness": <1-5>,
  "usefulness": <1-5>,
  "feedback": "<one concise sentence explaining the main strength or weakness>"
}}"""

    result = llm.invoke([HumanMessage(content=prompt)])

    try:
        scores = json.loads(result.content)
    except json.JSONDecodeError:
        match = re.search(r'\{.*\}', result.content, re.DOTALL)
        scores = json.loads(match.group()) if match else {}

    # Normalise: some models return 'actionability' instead of 'usefulness'
    if "usefulness" not in scores and "actionability" in scores:
        scores["usefulness"] = scores.pop("actionability")

    # Fill any missing keys with a neutral score
    for key in ("accuracy", "relevance", "completeness", "usefulness"):
        scores.setdefault(key, 1)
    scores.setdefault("feedback", "Could not parse evaluator output")

    scores["composite_score"] = round(
        (scores["accuracy"] + scores["relevance"] + scores["completeness"] + scores["usefulness"]) / 4, 2
    )
    return scores

# %%
from langchain_core.messages import ToolMessage

def evaluate_tool_usage(messages, expected_tools):
    """Evaluate whether the expected tools were called in the agent's message history."""
    tools_used = []
    for msg in messages:
        if isinstance(msg, ToolMessage) and msg.name not in tools_used:
            tools_used.append(msg.name)

    expected = set(expected_tools)
    used = set(tools_used)
    matched = expected & used
    extra = sorted(used - expected)
    missing = sorted(expected - used)

    completeness_pct = round(len(matched) / len(expected) * 100, 1) if expected else 100.0
    appropriateness_pct = round(len(matched) / len(used) * 100, 1) if used else 0.0

    parts = []
    if missing:
        parts.append(f"Missing tools: {', '.join(missing)}.")
    if extra:
        parts.append(f"Unexpected tools used: {', '.join(extra)}.")
    if not missing and not extra:
        parts.append("All expected tools used with no unnecessary calls.")
    feedback = " ".join(parts)

    return {
        "tools_used": tools_used,
        "expected_tools": expected_tools,
        "completeness_pct": completeness_pct,
        "appropriateness_pct": appropriateness_pct,
        "missing_tools": missing,
        "extra_tools": extra,
        "feedback": feedback,
    }

# %%
def display_evaluation_report(df):
    sep = "=" * 70
    print(sep)
    print("              ECOHOME AGENT EVALUATION REPORT")
    print(sep)

    cols = ["test_id", "accuracy", "relevance", "completeness", "usefulness",
            "composite_score", "tool_completeness_pct", "tool_appropriateness_pct", "passed"]
    print(df[cols].to_string(index=False))

    print("\n--- Summary Metrics ---")
    for dim in ["accuracy", "relevance", "completeness", "usefulness", "composite_score"]:
        print(f"  Avg {dim:<22}: {df[dim].mean():.2f} / 5.0")
    print(f"  Avg tool completeness    : {df['tool_completeness_pct'].mean():.1f}%")
    print(f"  Avg tool appropriateness : {df['tool_appropriateness_pct'].mean():.1f}%")
    print(f"  Tests passed             : {df['passed'].sum()} / {len(df)}")

    print("\n--- Strengths ---")
    strong = df[df["composite_score"] >= 4.0]["test_id"].tolist()
    print("  " + (", ".join(strong) if strong else "No tests scored 4.0 or above yet."))

    print("\n--- Weaknesses ---")
    weak = df[df["composite_score"] < 3.0]["test_id"].tolist()
    print("  " + (", ".join(weak) if weak else "No tests scored below 3.0."))

    print("\n--- Recommendations ---")
    recs = []
    for dim in ["accuracy", "relevance", "completeness", "usefulness"]:
        if df[dim].mean() < 3.5:
            recs.append(f"Improve {dim} (avg {df[dim].mean():.2f}): refine the system prompt guidance for this dimension.")
    if df["tool_completeness_pct"].mean() < 60:
        low = df[df["tool_completeness_pct"] < 50]["test_id"].tolist()
        recs.append(f"Tool coverage is low in: {', '.join(low)}. Review expected_tools or strengthen tool-calling instructions.")
    if df["tool_appropriateness_pct"].mean() < 70:
        recs.append("Agent is calling tools outside the expected set. Tighten the tool descriptions or prompt.")
    if not recs:
        recs.append("Performance is solid across all dimensions. Consider adding edge-case test scenarios.")
    for r in recs:
        print(f"  - {r}")

    print(sep)


def generate_evaluation_report():
    rows = []

    for result in test_results:
        if "error" in result:
            rows.append({
                "test_id": result["test_id"],
                "accuracy": 0, "relevance": 0, "completeness": 0, "usefulness": 0,
                "composite_score": 0.0,
                "tool_completeness_pct": 0.0,
                "tool_appropriateness_pct": 0.0,
                "missing_tools": ", ".join(result["expected_tools"]),
                "response_feedback": result["error"],
                "tool_feedback": "",
                "passed": False
            })
            continue

        messages = result["response"].get("messages", [])
        final_response = messages[-1].content if messages else ""

        response_scores = evaluate_response(result["question"], final_response, result["expected_response"])
        tool_scores = evaluate_tool_usage(messages, result["expected_tools"])

        passed = response_scores["composite_score"] >= 3.0 and tool_scores["completeness_pct"] >= 50.0

        rows.append({
            "test_id": result["test_id"],
            "accuracy": response_scores["accuracy"],
            "relevance": response_scores["relevance"],
            "completeness": response_scores["completeness"],
            "usefulness": response_scores["usefulness"],
            "composite_score": response_scores["composite_score"],
            "tool_completeness_pct": tool_scores["completeness_pct"],
            "tool_appropriateness_pct": tool_scores["appropriateness_pct"],
            "missing_tools": ", ".join(tool_scores["missing_tools"]) if tool_scores["missing_tools"] else "-",
            "response_feedback": response_scores["feedback"],
            "tool_feedback": tool_scores["feedback"],
            "passed": passed
        })

    df = pd.DataFrame(rows)
    display_evaluation_report(df)
    return df

# %%
evaluation_df = generate_evaluation_report()
# Out:
# ======================================================================
#               ECOHOME AGENT EVALUATION REPORT
# ======================================================================
#              test_id  accuracy  relevance  completeness  usefulness  composite_score  tool_completeness_pct  tool_appropriateness_pct  passed
#        ev_charging_1         5          5             5           5             5.00                  100.0                     100.0    True
#         thermostat_1         5          5             4           5             4.75                   66.7                     100.0    True
#      usage_history_1         3          4             3           4             3.50                  100.0                     100.0    True
# dishwasher_savings_1         2          3             2           2             2.25                  100.0                     100.0   False
#          pool_pump_1         5          5             5           5             5.00                   50.0                     100.0    True
#     solar_forecast_1         3          4             2           3             3.00                   50.0                     100.0    True
#      hvac_heatwave_1         4          5             4           4             4.25                   33.3                     100.0   False
# laundry_scheduling_1         5          5             5           5             5.00                  100.0                     100.0    True
#     cost_breakdown_1         1          2             1           2             1.50                   50.0                     100.0   False
#   battery_strategy_1         4          5             4           4             4.25                   66.7                      66.7    True
#
# --- Summary Metrics ---
#   Avg accuracy              : 3.70 / 5.0
#   Avg relevance             : 4.30 / 5.0
#   Avg completeness          : 3.50 / 5.0
#   Avg usefulness            : 3.90 / 5.0
#   Avg composite_score       : 3.85 / 5.0
#   Avg tool completeness    : 71.7%
#   Avg tool appropriateness : 96.7%
#   Tests passed             : 7 / 10
#
# --- Strengths ---
#   ev_charging_1, thermostat_1, pool_pump_1, hvac_heatwave_1, laundry_scheduling_1, battery_strategy_1
#
# --- Weaknesses ---
#   dishwasher_savings_1, cost_breakdown_1
#
# --- Recommendations ---
#   - Performance is solid across all dimensions. Consider adding edge-case test scenarios.
# ======================================================================
