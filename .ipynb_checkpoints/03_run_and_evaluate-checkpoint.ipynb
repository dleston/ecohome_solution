# %% [markdown]
# # EcoHome Energy Advisor - Agent Run & Evaluation
#
# In this notebook, you'll run the Energy Advisor agent with various real-world scenarios and see how it helps customers optimize their energy usage.
#
# ## Learning Objectives
# - Create the agent's instructions
# - Run the Energy Advisor with different types of questions
# - Evaluate response quality and accuracy
# - Measure tool usage effectiveness
# - Identify areas for improvement
# - Implement evaluation metrics
#
# ## Evaluation Criteria
# - **Accuracy**: Correct information and calculations
# - **Relevance**: Responses address the user's question
# - **Completeness**: Comprehensive answers with actionable advice
# - **Tool Usage**: Appropriate use of available tools
# - **Reasoning**: Clear explanation of recommendations

# %% [markdown]
# ## 1. Import and Initialize

# %%
from datetime import datetime
from agent import Agent

# %%
ECOHOME_SYSTEM_PROMPT = """You are EcoHome, an AI energy advisor for smart home owners. \
Your expertise covers solar generation, EV charging, HVAC, smart appliances, energy storage, and time-of-use electricity pricing.

Your goal is to help users minimize electricity costs, maximize solar self-consumption, and reduce energy waste \
through specific, data-driven recommendations.

Tools available to you:
- get_weather_forecast: hourly temperature, solar irradiance, and weather conditions by location
- get_electricity_prices: time-of-use (TOU) hourly rates with peak/off-peak/mid-peak windows
- query_energy_usage: historical device consumption by date range and device type
- query_solar_generation: historical solar production records
- get_recent_energy_summary: last N hours of usage and generation in one call
- search_energy_tips: retrieve efficiency tips and best practices from the knowledge base
- calculate_energy_savings: compute exact kWh and USD savings from any optimization scenario

Guidelines:
1. Always call get_weather_forecast and get_electricity_prices before making any scheduling recommendation.
2. Query historical usage or solar data when the question involves patterns, trends, or comparisons.
3. Give concrete answers: exact hours, specific temperatures (°F and °C), dollar amounts, and percentages.
4. Lead every scheduling recommendation with the optimal time window and explain why.
5. Include cost or savings figures in every recommendation — users need numbers to act.
6. Use the location from context when provided; default to typical U.S. TOU pricing when not.
7. When multiple devices compete for off-peak or solar windows, prioritize by energy intensity (kWh/cycle).
8. Keep responses concise and structured. Use short bullet points for lists of recommendations.
"""

# %%
ecohome_agent = Agent(
    instructions=ECOHOME_SYSTEM_PROMPT,
)

# %%
response = ecohome_agent.invoke(
    question="When should I charge my electric car tomorrow to minimize cost and maximize solar power?",
    context="Location: San Francisco, CA")

# %%
print(response["messages"][-1].content)
# Out:
# To minimize cost and maximize solar power when charging your electric car tomorrow in San Francisco:
#
# - **Optimal Time Window: Off-Peak (12:00 AM - 6:00 AM)**
#   - During this period, electricity rates are the lowest at $0.08 per kWh.
#
# - **Solar Power Availability:**
#   - Peak solar hours are from 8:00 AM to 6:00 PM, with the highest solar irradiance during the day.
#
# - **Charging Recommendations:**
#   1. **Overnight Charging (12:00 AM - 6:00 AM):**
#      - Charge your electric car during the off-peak hours when electricity rates are the lowest.
#      - Maximize solar self-consumption by ensuring the car is fully charged before the peak solar hours begin.
#
# - **Cost Savings:**
#   - By charging during the off-peak window, you can save on electricity costs compared to peak and mid-peak hours.
#   - Calculate the exact savings based on your car's charging requirements and the optimized charging schedule.

# %%
print("TOOLS:")
for msg in response["messages"]:
    if hasattr(msg, "tool_call_id") and msg.tool_call_id:
        print("-", msg.name)
# Out:
# TOOLS:
# - get_weather_forecast
# - get_electricity_prices

# %% [markdown]
# ## 2. Define Test Cases

# %%
test_cases = [
    {
        "id": "ev_charging_1",
        "question": "When should I charge my electric car tomorrow to minimize cost and maximize solar power?",
        "expected_tools": ["get_weather_forecast", "get_electricity_prices"],
        "expected_response": "Should recommend specific hours, mention off-peak rates, and reference solar generation window",
    },
    {
        "id": "thermostat_1",
        "question": "What temperature should I set my thermostat to on Wednesday afternoon when electricity prices spike?",
        "expected_tools": ["get_electricity_prices", "get_weather_forecast", "search_energy_tips"],
        "expected_response": "Should recommend pre-cooling before peak window, give specific setpoint in °F, and mention peak hours",
    },
    {
        "id": "usage_history_1",
        "question": "Suggest three ways I can reduce my energy use based on my usage history.",
        "expected_tools": ["get_recent_energy_summary", "search_energy_tips"],
        "expected_response": "Should list 3 specific recommendations based on device breakdown, with estimated savings per action",
    },
    {
        "id": "dishwasher_savings_1",
        "question": "How much can I save by running my dishwasher during off-peak hours instead of peak hours?",
        "expected_tools": ["get_electricity_prices", "calculate_energy_savings"],
        "expected_response": "Should compute savings in USD using peak vs off-peak rate difference and typical dishwasher kWh usage",
    },
    {
        "id": "pool_pump_1",
        "question": "What is the best time to run my pool pump this week based on the weather forecast?",
        "expected_tools": ["get_weather_forecast", "get_electricity_prices"],
        "expected_response": "Should give specific daily time windows combining off-peak rates and solar availability across 3+ days",
    },
    {
        "id": "solar_forecast_1",
        "question": "How much solar power can I expect to generate over the next 3 days?",
        "expected_tools": ["get_weather_forecast", "query_solar_generation"],
        "expected_response": "Should give a daily kWh estimate per day based on irradiance and compare to historical average",
    },
    {
        "id": "hvac_heatwave_1",
        "question": "How should I manage my HVAC system during a heat wave to keep costs down?",
        "expected_tools": ["get_weather_forecast", "get_electricity_prices", "search_energy_tips"],
        "expected_response": "Should recommend pre-cooling schedule, specific setpoints, and HVAC efficiency tips with cost impact",
    },
    {
        "id": "laundry_scheduling_1",
        "question": "When is the best time to run my washing machine and dryer this weekend?",
        "expected_tools": ["get_electricity_prices", "get_weather_forecast"],
        "expected_response": "Should suggest specific hours on Saturday/Sunday using off-peak rates and/or solar window",
    },
    {
        "id": "cost_breakdown_1",
        "question": "Give me a breakdown of my energy costs over the past week and flag any unusually high usage.",
        "expected_tools": ["query_energy_usage", "get_recent_energy_summary"],
        "expected_response": "Should show per-device kWh and cost totals, identify the highest consuming device, and flag anomalies",
    },
    {
        "id": "battery_strategy_1",
        "question": "What is the best strategy for charging and discharging my home battery this week?",
        "expected_tools": ["get_electricity_prices", "get_weather_forecast", "search_energy_tips"],
        "expected_response": "Should recommend charge during off-peak or solar peak and discharge during high-rate window with estimated savings",
    },
]

if len(test_cases) < 10:
    raise ValueError("You MUST have at least 10 test cases")

# %%
print(f"Loaded {len(test_cases)} test cases.")
# Out:
# Loaded 10 test cases.

# %% [markdown]
# ## 3. Run Agent Tests

# %%
CONTEXT = "Location: San Francisco, CA"

# %%
# Run the agent tests
# For each test case, call the agent and collect the response
# Store results for evaluation

print("=== Running Agent Tests ===")
test_results = []

for i, test_case in enumerate(test_cases):
    print(f"\nTest {i+1}: {test_case['id']}")
    print(f"Question: {test_case['question']}")
    print("-" * 50)
    
    try:
        # Call the agent
        response = ecohome_agent.invoke(
            question=test_case['question'],
            context=CONTEXT
        )
        
        # Store the result
        result = {
            'test_id': test_case['id'],
            'question': test_case['question'],
            'response': response,
            'expected_tools': test_case['expected_tools'],
            'expected_response': test_case['expected_response'],
            'timestamp': datetime.now().isoformat()
        }
        test_results.append(result)
                
    except Exception as e:
        print(f"Error: {e}")
        result = {
            'test_id': test_case['id'],
            'question': test_case['question'],
            'response': f"Error: {str(e)}",
            'expected_tools': test_case['expected_tools'],
            'expected_response': test_case['expected_response'],
            'timestamp': datetime.now().isoformat(),
            'error': str(e)
        }
        test_results.append(result)

print(f"\nCompleted {len(test_results)} tests")
# Out:
# === Running Agent Tests ===
#
# Test 1: ev_charging_1
# Question: When should I charge my electric car tomorrow to minimize cost and maximize solar power?
# --------------------------------------------------
#
# Test 2: thermostat_1
# Question: What temperature should I set my thermostat to on Wednesday afternoon when electricity prices spike?
# --------------------------------------------------
#
# Test 3: usage_history_1
# Question: Suggest three ways I can reduce my energy use based on my usage history.
# --------------------------------------------------
# C:\Users\U329114\OneDrive - IBERDROLA S.A\Formación\Nanodegrees\Agentic AI Engineer\Building AI Agents with LangGraph\ecohome_solution\tools.py:23: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   return OpenAIEmbeddings(
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event CollectionQueryEvent: capture() takes 1 positional argument but 3 were given
# Test 4: dishwasher_savings_1
# Question: How much can I save by running my dishwasher during off-peak hours instead of peak hours?
# --------------------------------------------------
#
# Test 5: pool_pump_1
# Question: What is the best time to run my pool pump this week based on the weather forecast?
# --------------------------------------------------
#
# Test 6: solar_forecast_1
# Question: How much solar power can I expect to generate over the next 3 days?
# --------------------------------------------------
#
# Test 7: hvac_heatwave_1
# Question: How should I manage my HVAC system during a heat wave to keep costs down?
# --------------------------------------------------
#
# Test 8: laundry_scheduling_1
# Question: When is the best time to run my washing machine and dryer this weekend?
# --------------------------------------------------
#
# Test 9: cost_breakdown_1
# Question: Give me a breakdown of my energy costs over the past week and flag any unusually high usage.
# --------------------------------------------------
#
# Test 10: battery_strategy_1
# Question: What is the best strategy for charging and discharging my home battery this week?
# --------------------------------------------------
#
# Completed 10 tests

# %%
test_results
# Out:
# [{'test_id': 'ev_charging_1',
#   'question': 'When should I charge my electric car tomorrow to minimize cost and maximize solar power?',
#   'response': {'messages': [SystemMessage(content='You are EcoHome, an AI energy advisor for smart home owners. Your expertise covers solar generation, EV charging, HVAC, smart appliances, energy storage, and time-of-use electricity pricing.\n\nYour goal is to help users minimize electricity costs, maximize solar self-consumption, and reduce energy waste through specific, data-driven recommendations.\n\nTools available to you:\n- get_weather_forecast: hourly temperature, solar irradiance, and weather conditions by location\n- get_electricity_prices: time-of-use (TOU) hourly rates with peak/off-peak/mid-peak windows\n- query_energy_usage: historical device consumption by date range and device type\n- query_solar_generation: historical solar production records\n- get_recent_energy_summary: last N hours of usage and generation in one call\n- search_energy_tips: retrieve efficiency tips and best practices from the knowledge base\n- calculate_energy_savings: compute exact kWh and USD savings from any optimization scenario\n\nGuidelines:\n1. Always call get_weather_forecast and get_electricity_prices before making any scheduling recommendation.\n2. Query historical usage or solar data when the question involves patterns, trends, or comparisons.\n3. Give concrete answers: exact hours, specific temperatures (°F and °C), dollar amounts, and percentages.\n4. Lead every scheduling recommendation with the optimal time window and explain why.\n5. Include cost or savings figures in every recommendation — users need numbers to act.\n6. Use the location from context when provided; default to typical U.S. TOU pricing when not.\n7. When multiple devices compete for off-peak or solar windows, prioritize by energy intensity (kWh/cycle).\n8. Keep responses concise and structured. Use short bullet points for lists of recommendations.\n', id='699adddf-475f-4d67-a58d-4e7e816d90b0'),
#     SystemMessage(content='Location: San Francisco, CA', id='23ef8b9f-7f1b-473a-beb3-4db911ec4e5d'),
#     HumanMessage(content='When should I charge my electric car tomorrow to minimize cost and maximize solar power?', id='c534c1c9-a3da-4ed8-b377-a1cbc7c4aeb5'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_jnFdYYiUWEzWvvNgrjVN2R5X', 'function': {'arguments': '{"location":"San Francisco, CA","days":1}', 'name': 'get_weather_forecast'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1060, 'total_tokens': 1083, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-eb2ff134-e9e6-4994-80e2-fd1069e4a7e9-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 1}, 'id': 'call_jnFdYYiUWEzWvvNgrjVN2R5X', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1060, 'output_tokens': 23, 'total_tokens': 1083}),
#     ToolMessage(content='{"location": "San Francisco, CA", "forecast_days": 1, "current": {"temperature_c": 14.4, "condition": "sunny", "humidity": 65, "wind_speed": 5.2}, "daily_forecast": [{"date": "2026-03-18", "condition": "sunny", "max_temp_c": 15.5, "min_temp_c": 9.5, "peak_solar_start": 8, "peak_solar_end": 18, "hourly": [{"hour": 0, "temperature_c": 9.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 38, "wind_speed": 19.4}, {"hour": 1, "temperature_c": 9.5, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 30, "wind_speed": 17.9}, {"hour": 2, "temperature_c": 9.3, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 41, "wind_speed": 20.5}, {"hour": 3, "temperature_c": 9.8, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 71, "wind_speed": 15.4}, {"hour": 4, "temperature_c": 9.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 75, "wind_speed": 5.9}, {"hour": 5, "temperature_c": 9.3, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 72, "wind_speed": 16.3}, {"hour": 6, "temperature_c": 9.4, "condition": "sunny", "solar_irradiance": 79.2, "humidity": 40, "wind_speed": 6.0}, {"hour": 7, "temperature_c": 10.6, "condition": "sunny", "solar_irradiance": 128.5, "humidity": 39, "wind_speed": 21.0}, {"hour": 8, "temperature_c": 10.7, "condition": "sunny", "solar_irradiance": 270.0, "humidity": 57, "wind_speed": 5.7}, {"hour": 9, "temperature_c": 11.1, "condition": "sunny", "solar_irradiance": 379.1, "humidity": 61, "wind_speed": 18.1}, {"hour": 10, "temperature_c": 11.8, "condition": "sunny", "solar_irradiance": 533.1, "humidity": 46, "wind_speed": 20.2}, {"hour": 11, "temperature_c": 12.8, "condition": "sunny", "solar_irradiance": 712.5, "humidity": 31, "wind_speed": 5.3}, {"hour": 12, "temperature_c": 13.9, "condition": "sunny", "solar_irradiance": 805.2, "humidity": 44, "wind_speed": 19.4}, {"hour": 13, "temperature_c": 13.8, "condition": "sunny", "solar_irradiance": 871.5, "humidity": 70, "wind_speed": 17.2}, {"hour": 14, "temperature_c": 15.3, "condition": "sunny", "solar_irradiance": 792.6, "humidity": 63, "wind_speed": 12.2}, {"hour": 15, "temperature_c": 15.7, "condition": "sunny", "solar_irradiance": 686.9, "humidity": 71, "wind_speed": 10.6}, {"hour": 16, "temperature_c": 14.7, "condition": "sunny", "solar_irradiance": 533.4, "humidity": 66, "wind_speed": 19.0}, {"hour": 17, "temperature_c": 13.9, "condition": "sunny", "solar_irradiance": 382.6, "humidity": 74, "wind_speed": 12.9}, {"hour": 18, "temperature_c": 12.8, "condition": "sunny", "solar_irradiance": 254.5, "humidity": 43, "wind_speed": 12.4}, {"hour": 19, "temperature_c": 13.0, "condition": "sunny", "solar_irradiance": 123.6, "humidity": 62, "wind_speed": 11.5}, {"hour": 20, "temperature_c": 11.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 41, "wind_speed": 17.4}, {"hour": 21, "temperature_c": 11.3, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 43, "wind_speed": 10.9}, {"hour": 22, "temperature_c": 9.8, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 73, "wind_speed": 6.5}, {"hour": 23, "temperature_c": 9.2, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 54, "wind_speed": 6.4}]}]}', name='get_weather_forecast', id='681c3fba-d0b5-43ac-b7c2-a5885c663b35', tool_call_id='call_jnFdYYiUWEzWvvNgrjVN2R5X'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_mUbg1raWc3zEB6KhvJKbQQQL', 'function': {'arguments': '{}', 'name': 'get_electricity_prices'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 2386, 'total_tokens': 2399, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-da28cac9-cac9-42ae-915c-ef34e4a8ce4f-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {}, 'id': 'call_mUbg1raWc3zEB6KhvJKbQQQL', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2386, 'output_tokens': 13, 'total_tokens': 2399}),
#     ToolMessage(content='{"date": "2026-03-18", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 7, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 8, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 9, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 10, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 11, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 12, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 13, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 14, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 15, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 16, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 17, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 18, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 19, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 20, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 21, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 22, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}], "peak_hours": [16, 17, 18, 19, 20], "off_peak_hours": [0, 1, 2, 3, 4, 5, 6, 23], "mid_peak_hours": [7, 8, 9, 10, 11, 12, 13, 14, 15, 21, 22], "cheapest_window_start": 0, "cheapest_window_end": 6, "daily_average_rate": 0.1538}', name='get_electricity_prices', id='97f2f8a4-b1b1-4abc-9d23-645ae39e9928', tool_call_id='call_mUbg1raWc3zEB6KhvJKbQQQL'),
#     AIMessage(content='To minimize cost and maximize solar power when charging your electric car tomorrow in San Francisco:\n\n- **Cheapest Charging Window**: \n  - **Off-Peak Hours**: 12:00 AM to 6:00 AM\n  - **Rate**: $0.08 per kWh\n\n- **Optimal Solar Generation Window**:\n  - **Peak Solar Hours**: 8:00 AM to 6:00 PM\n  - **Highest Solar Irradiance**: 805.2 W/m² at 12:00 PM\n\n- **Electricity Pricing**:\n  - **Peak Hours (Highest Rate)**: 4:00 PM to 9:00 PM\n  - **Peak Rate**: $0.28 per kWh\n\nBy charging your electric car during the off-peak hours, you can minimize costs and maximize solar power utilization.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 174, 'prompt_tokens': 3279, 'total_tokens': 3453, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-71efc5d5-fca8-401a-8882-b4f18d1bec15-0', usage_metadata={'input_tokens': 3279, 'output_tokens': 174, 'total_tokens': 3453})]},
#   'expected_tools': ['get_weather_forecast', 'get_electricity_prices'],
#   'expected_response': 'Should recommend specific hours, mention off-peak rates, and reference solar generation window',
#   'timestamp': '2026-03-18T01:21:54.992961'},
#  {'test_id': 'thermostat_1',
#   'question': 'What temperature should I set my thermostat to on Wednesday afternoon when electricity prices spike?',
#   'response': {'messages': [SystemMessage(content='You are EcoHome, an AI energy advisor for smart home owners. Your expertise covers solar generation, EV charging, HVAC, smart appliances, energy storage, and time-of-use electricity pricing.\n\nYour goal is to help users minimize electricity costs, maximize solar self-consumption, and reduce energy waste through specific, data-driven recommendations.\n\nTools available to you:\n- get_weather_forecast: hourly temperature, solar irradiance, and weather conditions by location\n- get_electricity_prices: time-of-use (TOU) hourly rates with peak/off-peak/mid-peak windows\n- query_energy_usage: historical device consumption by date range and device type\n- query_solar_generation: historical solar production records\n- get_recent_energy_summary: last N hours of usage and generation in one call\n- search_energy_tips: retrieve efficiency tips and best practices from the knowledge base\n- calculate_energy_savings: compute exact kWh and USD savings from any optimization scenario\n\nGuidelines:\n1. Always call get_weather_forecast and get_electricity_prices before making any scheduling recommendation.\n2. Query historical usage or solar data when the question involves patterns, trends, or comparisons.\n3. Give concrete answers: exact hours, specific temperatures (°F and °C), dollar amounts, and percentages.\n4. Lead every scheduling recommendation with the optimal time window and explain why.\n5. Include cost or savings figures in every recommendation — users need numbers to act.\n6. Use the location from context when provided; default to typical U.S. TOU pricing when not.\n7. When multiple devices compete for off-peak or solar windows, prioritize by energy intensity (kWh/cycle).\n8. Keep responses concise and structured. Use short bullet points for lists of recommendations.\n', id='1f8b5bb0-4e08-42e1-a4bb-c05dc850684d'),
#     SystemMessage(content='Location: San Francisco, CA', id='365ecaca-3f4b-412e-88e3-e333ae210f43'),
#     HumanMessage(content='What temperature should I set my thermostat to on Wednesday afternoon when electricity prices spike?', id='6074429c-61b1-402f-8c8a-1da36abae6b8'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_UR4j8vPKP8uWrKnkRASZ3Pfp', 'function': {'arguments': '{"location":"San Francisco, CA","days":1}', 'name': 'get_weather_forecast'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1060, 'total_tokens': 1083, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ac869412-c62a-4bc0-9222-39a9dbb51305-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 1}, 'id': 'call_UR4j8vPKP8uWrKnkRASZ3Pfp', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1060, 'output_tokens': 23, 'total_tokens': 1083}),
#     ToolMessage(content='{"location": "San Francisco, CA", "forecast_days": 1, "current": {"temperature_c": 14.4, "condition": "sunny", "humidity": 65, "wind_speed": 5.2}, "daily_forecast": [{"date": "2026-03-18", "condition": "sunny", "max_temp_c": 15.5, "min_temp_c": 9.5, "peak_solar_start": 8, "peak_solar_end": 18, "hourly": [{"hour": 0, "temperature_c": 9.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 38, "wind_speed": 19.4}, {"hour": 1, "temperature_c": 9.5, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 30, "wind_speed": 17.9}, {"hour": 2, "temperature_c": 9.3, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 41, "wind_speed": 20.5}, {"hour": 3, "temperature_c": 9.8, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 71, "wind_speed": 15.4}, {"hour": 4, "temperature_c": 9.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 75, "wind_speed": 5.9}, {"hour": 5, "temperature_c": 9.3, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 72, "wind_speed": 16.3}, {"hour": 6, "temperature_c": 9.4, "condition": "sunny", "solar_irradiance": 79.2, "humidity": 40, "wind_speed": 6.0}, {"hour": 7, "temperature_c": 10.6, "condition": "sunny", "solar_irradiance": 128.5, "humidity": 39, "wind_speed": 21.0}, {"hour": 8, "temperature_c": 10.7, "condition": "sunny", "solar_irradiance": 270.0, "humidity": 57, "wind_speed": 5.7}, {"hour": 9, "temperature_c": 11.1, "condition": "sunny", "solar_irradiance": 379.1, "humidity": 61, "wind_speed": 18.1}, {"hour": 10, "temperature_c": 11.8, "condition": "sunny", "solar_irradiance": 533.1, "humidity": 46, "wind_speed": 20.2}, {"hour": 11, "temperature_c": 12.8, "condition": "sunny", "solar_irradiance": 712.5, "humidity": 31, "wind_speed": 5.3}, {"hour": 12, "temperature_c": 13.9, "condition": "sunny", "solar_irradiance": 805.2, "humidity": 44, "wind_speed": 19.4}, {"hour": 13, "temperature_c": 13.8, "condition": "sunny", "solar_irradiance": 871.5, "humidity": 70, "wind_speed": 17.2}, {"hour": 14, "temperature_c": 15.3, "condition": "sunny", "solar_irradiance": 792.6, "humidity": 63, "wind_speed": 12.2}, {"hour": 15, "temperature_c": 15.7, "condition": "sunny", "solar_irradiance": 686.9, "humidity": 71, "wind_speed": 10.6}, {"hour": 16, "temperature_c": 14.7, "condition": "sunny", "solar_irradiance": 533.4, "humidity": 66, "wind_speed": 19.0}, {"hour": 17, "temperature_c": 13.9, "condition": "sunny", "solar_irradiance": 382.6, "humidity": 74, "wind_speed": 12.9}, {"hour": 18, "temperature_c": 12.8, "condition": "sunny", "solar_irradiance": 254.5, "humidity": 43, "wind_speed": 12.4}, {"hour": 19, "temperature_c": 13.0, "condition": "sunny", "solar_irradiance": 123.6, "humidity": 62, "wind_speed": 11.5}, {"hour": 20, "temperature_c": 11.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 41, "wind_speed": 17.4}, {"hour": 21, "temperature_c": 11.3, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 43, "wind_speed": 10.9}, {"hour": 22, "temperature_c": 9.8, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 73, "wind_speed": 6.5}, {"hour": 23, "temperature_c": 9.2, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 54, "wind_speed": 6.4}]}]}', name='get_weather_forecast', id='0b583bb8-4481-4021-8ec5-6efbaf7e1646', tool_call_id='call_UR4j8vPKP8uWrKnkRASZ3Pfp'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_SiAaV1CJ0z9BVJsU4J2r1Nbs', 'function': {'arguments': '{"date":"2026-03-18"}', 'name': 'get_electricity_prices'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 2386, 'total_tokens': 2408, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-31482486-5364-4397-8677-44f2b0525794-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {'date': '2026-03-18'}, 'id': 'call_SiAaV1CJ0z9BVJsU4J2r1Nbs', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2386, 'output_tokens': 22, 'total_tokens': 2408}),
#     ToolMessage(content='{"date": "2026-03-18", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 7, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 8, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 9, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 10, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 11, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 12, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 13, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 14, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 15, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 16, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 17, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 18, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 19, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 20, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 21, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 22, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}], "peak_hours": [16, 17, 18, 19, 20], "off_peak_hours": [0, 1, 2, 3, 4, 5, 6, 23], "mid_peak_hours": [7, 8, 9, 10, 11, 12, 13, 14, 15, 21, 22], "cheapest_window_start": 0, "cheapest_window_end": 6, "daily_average_rate": 0.1538}', name='get_electricity_prices', id='a559b46c-03ee-45dd-8a81-5851ddecee0a', tool_call_id='call_SiAaV1CJ0z9BVJsU4J2r1Nbs'),
#     AIMessage(content='On Wednesday afternoon in San Francisco, CA, the electricity prices spike during the peak hours from 4:00 PM to 8:00 PM with rates at $0.28 per kWh.\n\nTo optimize your energy usage and minimize costs during this peak pricing period, consider the following recommendation:\n\n- **Optimal Temperature Setting:** \n  - Set your thermostat to a comfortable but energy-efficient temperature around 68°F (20°C) during the afternoon to reduce HVAC usage and lower electricity costs during the peak pricing hours. \n\nBy adjusting your thermostat to a slightly lower temperature during the peak pricing period, you can save on cooling costs while maintaining a comfortable indoor environment.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 133, 'prompt_tokens': 3288, 'total_tokens': 3421, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-fe95230c-ea55-43cb-b423-c519ce943815-0', usage_metadata={'input_tokens': 3288, 'output_tokens': 133, 'total_tokens': 3421})]},
#   'expected_tools': ['get_electricity_prices',
#    'get_weather_forecast',
#    'search_energy_tips'],
#   'expected_response': 'Should recommend pre-cooling before peak window, give specific setpoint in °F, and mention peak hours',
#   'timestamp': '2026-03-18T01:22:03.330153'},
#  {'test_id': 'usage_history_1',
#   'question': 'Suggest three ways I can reduce my energy use based on my usage history.',
#   'response': {'messages': [SystemMessage(content='You are EcoHome, an AI energy advisor for smart home owners. Your expertise covers solar generation, EV charging, HVAC, smart appliances, energy storage, and time-of-use electricity pricing.\n\nYour goal is to help users minimize electricity costs, maximize solar self-consumption, and reduce energy waste through specific, data-driven recommendations.\n\nTools available to you:\n- get_weather_forecast: hourly temperature, solar irradiance, and weather conditions by location\n- get_electricity_prices: time-of-use (TOU) hourly rates with peak/off-peak/mid-peak windows\n- query_energy_usage: historical device consumption by date range and device type\n- query_solar_generation: historical solar production records\n- get_recent_energy_summary: last N hours of usage and generation in one call\n- search_energy_tips: retrieve efficiency tips and best practices from the knowledge base\n- calculate_energy_savings: compute exact kWh and USD savings from any optimization scenario\n\nGuidelines:\n1. Always call get_weather_forecast and get_electricity_prices before making any scheduling recommendation.\n2. Query historical usage or solar data when the question involves patterns, trends, or comparisons.\n3. Give concrete answers: exact hours, specific temperatures (°F and °C), dollar amounts, and percentages.\n4. Lead every scheduling recommendation with the optimal time window and explain why.\n5. Include cost or savings figures in every recommendation — users need numbers to act.\n6. Use the location from context when provided; default to typical U.S. TOU pricing when not.\n7. When multiple devices compete for off-peak or solar windows, prioritize by energy intensity (kWh/cycle).\n8. Keep responses concise and structured. Use short bullet points for lists of recommendations.\n', id='d276d2ba-22b4-4474-863a-13b967cd4150'),
#     SystemMessage(content='Location: San Francisco, CA', id='372795bf-bc29-4eae-abe8-2ff517169996'),
#     HumanMessage(content='Suggest three ways I can reduce my energy use based on my usage history.', id='6565be85-4d99-44a6-8829-27336971e5fc'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_9j9hpwpa87y4BbkPaCY9p2Tf', 'function': {'arguments': '{"hours":720}', 'name': 'get_recent_energy_summary'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 1060, 'total_tokens': 1076, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-c7342377-f0c6-4318-923e-652d34e0d1b7-0', tool_calls=[{'name': 'get_recent_energy_summary', 'args': {'hours': 720}, 'id': 'call_9j9hpwpa87y4BbkPaCY9p2Tf', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1060, 'output_tokens': 16, 'total_tokens': 1076}),
#     ToolMessage(content='{"time_period_hours": 720, "usage": {"total_consumption_kwh": 8582.37, "total_cost_usd": 981.55, "device_breakdown": {"EV": {"consumption_kwh": 6300.62, "cost_usd": 715.21, "records": 694}, "HVAC": {"consumption_kwh": 1324.07, "cost_usd": 157.42, "records": 694}, "appliance": {"consumption_kwh": 957.68, "cost_usd": 108.92, "records": 694}}}, "generation": {"total_generation_kwh": 525.93, "average_weather": "sunny"}}', name='get_recent_energy_summary', id='5c8fdc90-e6c5-4060-9013-332ce6862161', tool_call_id='call_9j9hpwpa87y4BbkPaCY9p2Tf'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_aJSZkTUczSdTryKYuRayafAO', 'function': {'arguments': '{"query": "reduce HVAC energy use", "max_results": 1}', 'name': 'search_energy_tips'}, 'type': 'function'}, {'id': 'call_D5RX8C43R5C4R317eWEevFyw', 'function': {'arguments': '{"query": "reduce EV charging energy use", "max_results": 1}', 'name': 'search_energy_tips'}, 'type': 'function'}, {'id': 'call_4o7FjX9JqCILqGajoiIPQR8C', 'function': {'arguments': '{"query": "reduce appliance energy use", "max_results": 1}', 'name': 'search_energy_tips'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 85, 'prompt_tokens': 1243, 'total_tokens': 1328, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-18dc46c0-4206-4725-8f56-1333b99b51a1-0', tool_calls=[{'name': 'search_energy_tips', 'args': {'query': 'reduce HVAC energy use', 'max_results': 1}, 'id': 'call_aJSZkTUczSdTryKYuRayafAO', 'type': 'tool_call'}, {'name': 'search_energy_tips', 'args': {'query': 'reduce EV charging energy use', 'max_results': 1}, 'id': 'call_D5RX8C43R5C4R317eWEevFyw', 'type': 'tool_call'}, {'name': 'search_energy_tips', 'args': {'query': 'reduce appliance energy use', 'max_results': 1}, 'id': 'call_4o7FjX9JqCILqGajoiIPQR8C', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1243, 'output_tokens': 85, 'total_tokens': 1328}),
#     ToolMessage(content='{"query": "reduce HVAC energy use", "total_results": 1, "tips": [{"rank": 1, "content": "Use power strips to easily turn off multiple devices at once. Many electronics continue to draw power even when turned off, known as phantom load.\\n\\nConsider energy-efficient appliances when replacing old ones. Look for ENERGY STAR certified products that use 10-50% less energy than standard models.\\n\\nPlant trees or install awnings to provide shade for your home during summer months. This can reduce cooling costs by up to 25%.\\n\\nUse ceiling fans to circulate air and make rooms feel cooler, allowing you to raise the thermostat temperature by 4Â°F without discomfort.", "source": "data/documents/tip_energy_savings.txt", "relevance_score": "high"}]}', name='search_energy_tips', id='d8af2ecc-2ec6-4e21-8e00-97639e872ac0', tool_call_id='call_aJSZkTUczSdTryKYuRayafAO'),
#     ToolMessage(content='{"query": "reduce EV charging energy use", "total_results": 1, "tips": [{"rank": 1, "content": "Notification-driven optimization alerts occupants to high-cost or high-usage conditions: \\"Electricity prices are at peak rate until 9 PM. Consider delaying your dryer cycle.\\" These nudges, combined with energy dashboards, have been shown to reduce consumption by 8â€“12% through behavioral change alone.\\n\\nIntegration with weather APIs enables predictive automation. A cloudy forecast can trigger: preheating water with resistance elements the night before (when solar contribution will be low), pre-cooling or prewarming the home using off-peak power before an extreme temperature day, and postponing EV charging to a window with better grid carbon intensity.", "source": "data/documents/tip_smart_home_automation.txt", "relevance_score": "high"}]}', name='search_energy_tips', id='28f8e7c7-ef44-40b6-8a1f-66875e183f53', tool_call_id='call_D5RX8C43R5C4R317eWEevFyw'),
#     ToolMessage(content='{"query": "reduce appliance energy use", "total_results": 1, "tips": [{"rank": 1, "content": "Saving energy at home can be simple and effective. Turn off lights when not in use and unplug devices that draw standby power. Use natural lighting during the day and replace incandescent bulbs with energy-efficient LEDs. Keep appliances clean and well-maintained to ensure they operate efficiently.\\n\\nSmart thermostats can save up to 10% on heating and cooling costs by automatically adjusting temperatures when you\'re away. Set your thermostat to 68Â°F in winter and 78Â°F in summer for optimal energy savings.\\n\\nWash clothes in cold water and only run full loads. Use the dryer\'s moisture sensor instead of timed drying. Clean the lint filter after every load to improve efficiency.\\n\\nSeal air leaks around windows and doors with weatherstripping or caulk. Add insulation to attics and walls to reduce heating and cooling needs.\\n\\nUse power strips to easily turn off multiple devices at once. Many electronics continue to draw power even when turned off, known as phantom load.", "source": "data/documents/tip_energy_savings.txt", "relevance_score": "high"}]}', name='search_energy_tips', id='8974233d-5cf4-4e2b-9484-0ddb7c4ef1f6', tool_call_id='call_4o7FjX9JqCILqGajoiIPQR8C'),
#     AIMessage(content="Based on your energy usage history, here are three ways to reduce energy consumption:\n\n### Reduce HVAC Energy Use:\n- Use power strips to easily turn off multiple devices at once and eliminate phantom loads.\n- Consider energy-efficient appliances like ENERGY STAR certified products for lower energy consumption.\n- Provide shade with trees or awnings to reduce cooling costs by up to 25%.\n- Use ceiling fans to circulate air and raise the thermostat temperature by 4°F without discomfort.\n\n### Reduce EV Charging Energy Use:\n- Receive notification-driven optimization alerts to adjust high-cost or high-usage conditions.\n- Integrate with weather APIs for predictive automation to optimize energy usage based on weather forecasts.\n- Postpone EV charging to a window with better grid carbon intensity.\n\n### Reduce Appliance Energy Use:\n- Turn off lights when not in use and unplug devices drawing standby power.\n- Utilize natural lighting during the day and switch to energy-efficient LEDs.\n- Maintain appliances for efficient operation and use smart thermostats for automatic temperature adjustments.\n- Wash clothes in cold water, run full loads, and clean the dryer's lint filter regularly.\n- Seal air leaks, add insulation, and use power strips to eliminate phantom loads.\n\nImplementing these strategies can help you reduce energy consumption and lower your electricity costs.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 257, 'prompt_tokens': 1949, 'total_tokens': 2206, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-c9b5349a-04f4-4566-8111-c37f5123e5aa-0', usage_metadata={'input_tokens': 1949, 'output_tokens': 257, 'total_tokens': 2206})]},
#   'expected_tools': ['get_recent_energy_summary', 'search_energy_tips'],
#   'expected_response': 'Should list 3 specific recommendations based on device breakdown, with estimated savings per action',
#   'timestamp': '2026-03-18T01:22:17.973190'},
#  {'test_id': 'dishwasher_savings_1',
#   'question': 'How much can I save by running my dishwasher during off-peak hours instead of peak hours?',
#   'response': {'messages': [SystemMessage(content='You are EcoHome, an AI energy advisor for smart home owners. Your expertise covers solar generation, EV charging, HVAC, smart appliances, energy storage, and time-of-use electricity pricing.\n\nYour goal is to help users minimize electricity costs, maximize solar self-consumption, and reduce energy waste through specific, data-driven recommendations.\n\nTools available to you:\n- get_weather_forecast: hourly temperature, solar irradiance, and weather conditions by location\n- get_electricity_prices: time-of-use (TOU) hourly rates with peak/off-peak/mid-peak windows\n- query_energy_usage: historical device consumption by date range and device type\n- query_solar_generation: historical solar production records\n- get_recent_energy_summary: last N hours of usage and generation in one call\n- search_energy_tips: retrieve efficiency tips and best practices from the knowledge base\n- calculate_energy_savings: compute exact kWh and USD savings from any optimization scenario\n\nGuidelines:\n1. Always call get_weather_forecast and get_electricity_prices before making any scheduling recommendation.\n2. Query historical usage or solar data when the question involves patterns, trends, or comparisons.\n3. Give concrete answers: exact hours, specific temperatures (°F and °C), dollar amounts, and percentages.\n4. Lead every scheduling recommendation with the optimal time window and explain why.\n5. Include cost or savings figures in every recommendation — users need numbers to act.\n6. Use the location from context when provided; default to typical U.S. TOU pricing when not.\n7. When multiple devices compete for off-peak or solar windows, prioritize by energy intensity (kWh/cycle).\n8. Keep responses concise and structured. Use short bullet points for lists of recommendations.\n', id='e977a601-e314-46ab-ad69-06c13231dc5b'),
#     SystemMessage(content='Location: San Francisco, CA', id='9b0d5184-455e-4130-ae2b-6eda499d823a'),
#     HumanMessage(content='How much can I save by running my dishwasher during off-peak hours instead of peak hours?', id='7a9f5b15-40ac-43fe-8096-419c0f1127ef'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_qprrHAwl8rXpIv3ZRcl8Q1ph', 'function': {'arguments': '{}', 'name': 'get_electricity_prices'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 1063, 'total_tokens': 1076, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-bdb7113c-eb99-409c-818c-142789421aac-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {}, 'id': 'call_qprrHAwl8rXpIv3ZRcl8Q1ph', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1063, 'output_tokens': 13, 'total_tokens': 1076}),
#     ToolMessage(content='{"date": "2026-03-18", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 7, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 8, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 9, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 10, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 11, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 12, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 13, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 14, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 15, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 16, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 17, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 18, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 19, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 20, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 21, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 22, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}], "peak_hours": [16, 17, 18, 19, 20], "off_peak_hours": [0, 1, 2, 3, 4, 5, 6, 23], "mid_peak_hours": [7, 8, 9, 10, 11, 12, 13, 14, 15, 21, 22], "cheapest_window_start": 0, "cheapest_window_end": 6, "daily_average_rate": 0.1538}', name='get_electricity_prices', id='782e7cb2-3097-4eaa-b853-ed93b15ead31', tool_call_id='call_qprrHAwl8rXpIv3ZRcl8Q1ph'),
#     AIMessage(content="To save on electricity costs, you should run your dishwasher during off-peak hours when the rates are lower. Here are the details:\n\n- Off-peak hours: 12:00 AM to 6:00 AM and 11:00 PM\n- Peak hours: 4:00 PM to 9:00 PM\n- Off-peak rate: $0.08 per kWh\n- Peak rate: $0.28 per kWh\n\nNow, let's calculate the potential savings by running your dishwasher during off-peak hours instead of peak hours. To do this, I need to know the energy consumption of your dishwasher per cycle. Could you provide that information?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 137, 'prompt_tokens': 1956, 'total_tokens': 2093, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-76b548b5-35fa-4a33-bcb8-995f05233dac-0', usage_metadata={'input_tokens': 1956, 'output_tokens': 137, 'total_tokens': 2093})]},
#   'expected_tools': ['get_electricity_prices', 'calculate_energy_savings'],
#   'expected_response': 'Should compute savings in USD using peak vs off-peak rate difference and typical dishwasher kWh usage',
#   'timestamp': '2026-03-18T01:22:22.017671'},
#  {'test_id': 'pool_pump_1',
#   'question': 'What is the best time to run my pool pump this week based on the weather forecast?',
#   'response': {'messages': [SystemMessage(content='You are EcoHome, an AI energy advisor for smart home owners. Your expertise covers solar generation, EV charging, HVAC, smart appliances, energy storage, and time-of-use electricity pricing.\n\nYour goal is to help users minimize electricity costs, maximize solar self-consumption, and reduce energy waste through specific, data-driven recommendations.\n\nTools available to you:\n- get_weather_forecast: hourly temperature, solar irradiance, and weather conditions by location\n- get_electricity_prices: time-of-use (TOU) hourly rates with peak/off-peak/mid-peak windows\n- query_energy_usage: historical device consumption by date range and device type\n- query_solar_generation: historical solar production records\n- get_recent_energy_summary: last N hours of usage and generation in one call\n- search_energy_tips: retrieve efficiency tips and best practices from the knowledge base\n- calculate_energy_savings: compute exact kWh and USD savings from any optimization scenario\n\nGuidelines:\n1. Always call get_weather_forecast and get_electricity_prices before making any scheduling recommendation.\n2. Query historical usage or solar data when the question involves patterns, trends, or comparisons.\n3. Give concrete answers: exact hours, specific temperatures (°F and °C), dollar amounts, and percentages.\n4. Lead every scheduling recommendation with the optimal time window and explain why.\n5. Include cost or savings figures in every recommendation — users need numbers to act.\n6. Use the location from context when provided; default to typical U.S. TOU pricing when not.\n7. When multiple devices compete for off-peak or solar windows, prioritize by energy intensity (kWh/cycle).\n8. Keep responses concise and structured. Use short bullet points for lists of recommendations.\n', id='52e3d252-655e-4411-b911-449b76e0bfc7'),
#     SystemMessage(content='Location: San Francisco, CA', id='e6b2b351-85e5-45f5-a84b-66585e5091cd'),
#     HumanMessage(content='What is the best time to run my pool pump this week based on the weather forecast?', id='964c5d75-e0a1-417b-8e68-9262ad4e7f81'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_CuRRUsekTGJIPfOGuQJpOCUl', 'function': {'arguments': '{"location":"San Francisco, CA","days":7}', 'name': 'get_weather_forecast'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1062, 'total_tokens': 1085, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-4c418ae4-adec-42c1-94ce-096444a443f5-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 7}, 'id': 'call_CuRRUsekTGJIPfOGuQJpOCUl', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1062, 'output_tokens': 23, 'total_tokens': 1085}),
#     ToolMessage(content='{"location": "San Francisco, CA", "forecast_days": 7, "current": {"temperature_c": 14.4, "condition": "sunny", "humidity": 52, "wind_speed": 12.3}, "daily_forecast": [{"date": "2026-03-18", "condition": "sunny", "max_temp_c": 15.5, "min_temp_c": 9.5, "peak_solar_start": 8, "peak_solar_end": 18, "hourly": [{"hour": 0, "temperature_c": 9.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 38, "wind_speed": 19.4}, {"hour": 1, "temperature_c": 9.5, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 30, "wind_speed": 17.9}, {"hour": 2, "temperature_c": 9.3, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 41, "wind_speed": 20.5}, {"hour": 3, "temperature_c": 9.8, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 71, "wind_speed": 15.4}, {"hour": 4, "temperature_c": 9.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 75, "wind_speed": 5.9}, {"hour": 5, "temperature_c": 9.3, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 72, "wind_speed": 16.3}, {"hour": 6, "temperature_c": 9.4, "condition": "sunny", "solar_irradiance": 79.2, "humidity": 40, "wind_speed": 6.0}, {"hour": 7, "temperature_c": 10.6, "condition": "sunny", "solar_irradiance": 128.5, "humidity": 39, "wind_speed": 21.0}, {"hour": 8, "temperature_c": 10.7, "condition": "sunny", "solar_irradiance": 270.0, "humidity": 57, "wind_speed": 5.7}, {"hour": 9, "temperature_c": 11.1, "condition": "sunny", "solar_irradiance": 379.1, "humidity": 61, "wind_speed": 18.1}, {"hour": 10, "temperature_c": 11.8, "condition": "sunny", "solar_irradiance": 533.1, "humidity": 46, "wind_speed": 20.2}, {"hour": 11, "temperature_c": 12.8, "condition": "sunny", "solar_irradiance": 712.5, "humidity": 31, "wind_speed": 5.3}, {"hour": 12, "temperature_c": 13.9, "condition": "sunny", "solar_irradiance": 805.2, "humidity": 44, "wind_speed": 19.4}, {"hour": 13, "temperature_c": 13.8, "condition": "sunny", "solar_irradiance": 871.5, "humidity": 70, "wind_speed": 17.2}, {"hour": 14, "temperature_c": 15.3, "condition": "sunny", "solar_irradiance": 792.6, "humidity": 63, "wind_speed": 12.2}, {"hour": 15, "temperature_c": 15.7, "condition": "sunny", "solar_irradiance": 686.9, "humidity": 71, "wind_speed": 10.6}, {"hour": 16, "temperature_c": 14.7, "condition": "sunny", "solar_irradiance": 533.4, "humidity": 66, "wind_speed": 19.0}, {"hour": 17, "temperature_c": 13.9, "condition": "sunny", "solar_irradiance": 382.6, "humidity": 74, "wind_speed": 12.9}, {"hour": 18, "temperature_c": 12.8, "condition": "sunny", "solar_irradiance": 254.5, "humidity": 43, "wind_speed": 12.4}, {"hour": 19, "temperature_c": 13.0, "condition": "sunny", "solar_irradiance": 123.6, "humidity": 62, "wind_speed": 11.5}, {"hour": 20, "temperature_c": 11.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 41, "wind_speed": 17.4}, {"hour": 21, "temperature_c": 11.3, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 43, "wind_speed": 10.9}, {"hour": 22, "temperature_c": 9.8, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 73, "wind_speed": 6.5}, {"hour": 23, "temperature_c": 9.2, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 54, "wind_speed": 6.4}]}, {"date": "2026-03-19", "condition": "sunny", "max_temp_c": 21.2, "min_temp_c": 15.2, "peak_solar_start": 8, "peak_solar_end": 18, "hourly": [{"hour": 0, "temperature_c": 15.0, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 71, "wind_speed": 16.4}, {"hour": 1, "temperature_c": 15.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 33, "wind_speed": 19.1}, {"hour": 2, "temperature_c": 15.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 39, "wind_speed": 13.2}, {"hour": 3, "temperature_c": 14.9, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 30, "wind_speed": 7.2}, {"hour": 4, "temperature_c": 15.4, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 47, "wind_speed": 17.9}, {"hour": 5, "temperature_c": 15.6, "condition": " ...
# ...
#     AIMessage(content='It seems there is no energy usage data available for the past week. To provide insights into your energy costs and flag any unusual usage, I recommend checking your energy usage data for the previous week. Once you have the data available, I can analyze it to identify any anomalies or high consumption periods.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 60, 'prompt_tokens': 1164, 'total_tokens': 1224, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-ea5eed6c-b763-4917-ad14-6836fc0b615e-0', usage_metadata={'input_tokens': 1164, 'output_tokens': 60, 'total_tokens': 1224})]},
#   'expected_tools': ['query_energy_usage', 'get_recent_energy_summary'],
#   'expected_response': 'Should show per-device kWh and cost totals, identify the highest consuming device, and flag anomalies',
#   'timestamp': '2026-03-18T01:22:47.105330'},
#  {'test_id': 'battery_strategy_1',
#   'question': 'What is the best strategy for charging and discharging my home battery this week?',
#   'response': {'messages': [SystemMessage(content='You are EcoHome, an AI energy advisor for smart home owners. Your expertise covers solar generation, EV charging, HVAC, smart appliances, energy storage, and time-of-use electricity pricing.\n\nYour goal is to help users minimize electricity costs, maximize solar self-consumption, and reduce energy waste through specific, data-driven recommendations.\n\nTools available to you:\n- get_weather_forecast: hourly temperature, solar irradiance, and weather conditions by location\n- get_electricity_prices: time-of-use (TOU) hourly rates with peak/off-peak/mid-peak windows\n- query_energy_usage: historical device consumption by date range and device type\n- query_solar_generation: historical solar production records\n- get_recent_energy_summary: last N hours of usage and generation in one call\n- search_energy_tips: retrieve efficiency tips and best practices from the knowledge base\n- calculate_energy_savings: compute exact kWh and USD savings from any optimization scenario\n\nGuidelines:\n1. Always call get_weather_forecast and get_electricity_prices before making any scheduling recommendation.\n2. Query historical usage or solar data when the question involves patterns, trends, or comparisons.\n3. Give concrete answers: exact hours, specific temperatures (°F and °C), dollar amounts, and percentages.\n4. Lead every scheduling recommendation with the optimal time window and explain why.\n5. Include cost or savings figures in every recommendation — users need numbers to act.\n6. Use the location from context when provided; default to typical U.S. TOU pricing when not.\n7. When multiple devices compete for off-peak or solar windows, prioritize by energy intensity (kWh/cycle).\n8. Keep responses concise and structured. Use short bullet points for lists of recommendations.\n', id='be53a3a7-3af5-49e0-a710-defe5e49a2c5'),
#     SystemMessage(content='Location: San Francisco, CA', id='132af035-7295-4232-89b9-f89a2211da94'),
#     HumanMessage(content='What is the best strategy for charging and discharging my home battery this week?', id='74389fd0-b0a5-4142-aa0d-ae717d12b186'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_bKfNTNRawb0siz7pP9cdOPVt', 'function': {'arguments': '{"location":"San Francisco, CA","days":7}', 'name': 'get_weather_forecast'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1060, 'total_tokens': 1083, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-71b12da3-44ec-4589-aef3-a0cd8e54d923-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 7}, 'id': 'call_bKfNTNRawb0siz7pP9cdOPVt', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1060, 'output_tokens': 23, 'total_tokens': 1083}),
#     ToolMessage(content='{"location": "San Francisco, CA", "forecast_days": 7, "current": {"temperature_c": 14.4, "condition": "sunny", "humidity": 52, "wind_speed": 12.3}, "daily_forecast": [{"date": "2026-03-18", "condition": "sunny", "max_temp_c": 15.5, "min_temp_c": 9.5, "peak_solar_start": 8, "peak_solar_end": 18, "hourly": [{"hour": 0, "temperature_c": 9.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 38, "wind_speed": 19.4}, {"hour": 1, "temperature_c": 9.5, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 30, "wind_speed": 17.9}, {"hour": 2, "temperature_c": 9.3, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 41, "wind_speed": 20.5}, {"hour": 3, "temperature_c": 9.8, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 71, "wind_speed": 15.4}, {"hour": 4, "temperature_c": 9.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 75, "wind_speed": 5.9}, {"hour": 5, "temperature_c": 9.3, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 72, "wind_speed": 16.3}, {"hour": 6, "temperature_c": 9.4, "condition": "sunny", "solar_irradiance": 79.2, "humidity": 40, "wind_speed": 6.0}, {"hour": 7, "temperature_c": 10.6, "condition": "sunny", "solar_irradiance": 128.5, "humidity": 39, "wind_speed": 21.0}, {"hour": 8, "temperature_c": 10.7, "condition": "sunny", "solar_irradiance": 270.0, "humidity": 57, "wind_speed": 5.7}, {"hour": 9, "temperature_c": 11.1, "condition": "sunny", "solar_irradiance": 379.1, "humidity": 61, "wind_speed": 18.1}, {"hour": 10, "temperature_c": 11.8, "condition": "sunny", "solar_irradiance": 533.1, "humidity": 46, "wind_speed": 20.2}, {"hour": 11, "temperature_c": 12.8, "condition": "sunny", "solar_irradiance": 712.5, "humidity": 31, "wind_speed": 5.3}, {"hour": 12, "temperature_c": 13.9, "condition": "sunny", "solar_irradiance": 805.2, "humidity": 44, "wind_speed": 19.4}, {"hour": 13, "temperature_c": 13.8, "condition": "sunny", "solar_irradiance": 871.5, "humidity": 70, "wind_speed": 17.2}, {"hour": 14, "temperature_c": 15.3, "condition": "sunny", "solar_irradiance": 792.6, "humidity": 63, "wind_speed": 12.2}, {"hour": 15, "temperature_c": 15.7, "condition": "sunny", "solar_irradiance": 686.9, "humidity": 71, "wind_speed": 10.6}, {"hour": 16, "temperature_c": 14.7, "condition": "sunny", "solar_irradiance": 533.4, "humidity": 66, "wind_speed": 19.0}, {"hour": 17, "temperature_c": 13.9, "condition": "sunny", "solar_irradiance": 382.6, "humidity": 74, "wind_speed": 12.9}, {"hour": 18, "temperature_c": 12.8, "condition": "sunny", "solar_irradiance": 254.5, "humidity": 43, "wind_speed": 12.4}, {"hour": 19, "temperature_c": 13.0, "condition": "sunny", "solar_irradiance": 123.6, "humidity": 62, "wind_speed": 11.5}, {"hour": 20, "temperature_c": 11.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 41, "wind_speed": 17.4}, {"hour": 21, "temperature_c": 11.3, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 43, "wind_speed": 10.9}, {"hour": 22, "temperature_c": 9.8, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 73, "wind_speed": 6.5}, {"hour": 23, "temperature_c": 9.2, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 54, "wind_speed": 6.4}]}, {"date": "2026-03-19", "condition": "sunny", "max_temp_c": 21.2, "min_temp_c": 15.2, "peak_solar_start": 8, "peak_solar_end": 18, "hourly": [{"hour": 0, "temperature_c": 15.0, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 71, "wind_speed": 16.4}, {"hour": 1, "temperature_c": 15.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 33, "wind_speed": 19.1}, {"hour": 2, "temperature_c": 15.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 39, "wind_speed": 13.2}, {"hour": 3, "temperature_c": 14.9, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 30, "wind_speed": 7.2}, {"hour": 4, "temperature_c": 15.4, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 47, "wind_speed": 17.9}, {"hour": 5, "temperature_c": 15.6, "condition": " ...
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_E9ur4F9Dd1aW0yw1FpTIV0gW', 'function': {'arguments': '{"date":"2026-03-18"}', 'name': 'get_electricity_prices'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 9858, 'total_tokens': 9880, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-6d0f8b10-2ee0-4208-ae35-366839b41f3f-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {'date': '2026-03-18'}, 'id': 'call_E9ur4F9Dd1aW0yw1FpTIV0gW', 'type': 'tool_call'}], usage_metadata={'input_tokens': 9858, 'output_tokens': 22, 'total_tokens': 9880}),
#     ToolMessage(content='{"date": "2026-03-18", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}, {"hour": 7, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 8, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 9, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 10, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 11, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 12, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 13, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 14, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 15, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 16, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 17, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 18, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 19, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 20, "rate": 0.28, "period": "peak", "demand_charge": 0.028}, {"hour": 21, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 22, "rate": 0.15, "period": "mid_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.08, "period": "off_peak", "demand_charge": 0.0}], "peak_hours": [16, 17, 18, 19, 20], "off_peak_hours": [0, 1, 2, 3, 4, 5, 6, 23], "mid_peak_hours": [7, 8, 9, 10, 11, 12, 13, 14, 15, 21, 22], "cheapest_window_start": 0, "cheapest_window_end": 6, "daily_average_rate": 0.1538}', name='get_electricity_prices', id='d5b7c4b6-909f-412a-bc54-ae7e730a3675', tool_call_id='call_E9ur4F9Dd1aW0yw1FpTIV0gW'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_EcWPVziCkPN5PZvBkq8yDlgv', 'function': {'arguments': '{"start_date": "2026-03-18", "end_date": "2026-03-24"}', 'name': 'query_solar_generation'}, 'type': 'function'}, {'id': 'call_BGlb0bf5izQ3JKpvzoNklhSm', 'function': {'arguments': '{"start_date": "2026-03-18", "end_date": "2026-03-24", "device_type": "battery"}', 'name': 'query_energy_usage'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 83, 'prompt_tokens': 10760, 'total_tokens': 10843, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-cdb6c5d6-fbba-44c8-916b-73ef26ab82c0-0', tool_calls=[{'name': 'query_solar_generation', 'args': {'start_date': '2026-03-18', 'end_date': '2026-03-24'}, 'id': 'call_EcWPVziCkPN5PZvBkq8yDlgv', 'type': 'tool_call'}, {'name': 'query_energy_usage', 'args': {'start_date': '2026-03-18', 'end_date': '2026-03-24', 'device_type': 'battery'}, 'id': 'call_BGlb0bf5izQ3JKpvzoNklhSm', 'type': 'tool_call'}], usage_metadata={'input_tokens': 10760, 'output_tokens': 83, 'total_tokens': 10843}),
#     ToolMessage(content='{"start_date": "2026-03-18", "end_date": "2026-03-24", "total_records": 0, "total_generation_kwh": 0, "average_daily_generation": 0.0, "records": []}', name='query_solar_generation', id='4159b4dd-cd22-4b89-a803-1f5787c7c5fe', tool_call_id='call_EcWPVziCkPN5PZvBkq8yDlgv'),
#     ToolMessage(content='{"start_date": "2026-03-18", "end_date": "2026-03-24", "device_type": "battery", "total_records": 0, "total_consumption_kwh": 0, "total_cost_usd": 0, "records": []}', name='query_energy_usage', id='2eae5ac8-0678-4f76-9754-5ddd732e8b36', tool_call_id='call_BGlb0bf5izQ3JKpvzoNklhSm'),
#     AIMessage(content="I couldn't retrieve historical data for solar generation and battery consumption for this week. However, based on the weather forecast, electricity prices, and typical patterns, here is the optimal strategy for charging and discharging your home battery:\n\n- **Charging Strategy:**\n  - **Optimal Charging Window:** 12:00 AM to 6:00 AM (Off-Peak Hours)\n  - **Reasoning:** Electricity rates are lowest during off-peak hours, allowing you to charge the battery at the cheapest rates.\n\n- **Discharging Strategy:**\n  - **Peak Hours (4:00 PM to 9:00 PM):**\n    - Avoid discharging the battery during peak hours when electricity rates are highest.\n  - **Mid-Peak Hours (7:00 AM to 3:00 PM, 5:00 PM to 8:00 PM):**\n    - Consider using the battery during mid-peak hours if necessary, as rates are moderate.\n  - **Off-Peak Hours (10:00 PM to 6:00 AM):**\n    - Utilize the battery during off-peak hours to maximize savings and reduce reliance on the grid.\n\n- **Additional Recommendations:**\n  - Monitor solar generation to align battery charging with peak solar hours for maximum self-consumption.\n  - Consider energy-efficient practices to optimize battery usage and reduce overall electricity costs.\n\nIf you have historical data available, I can provide more tailored recommendations.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 297, 'prompt_tokens': 10971, 'total_tokens': 11268, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-c651a71d-c947-45b6-a16d-d0e5936601d2-0', usage_metadata={'input_tokens': 10971, 'output_tokens': 297, 'total_tokens': 11268})]},
#   'expected_tools': ['get_electricity_prices',
#    'get_weather_forecast',
#    'search_energy_tips'],
#   'expected_response': 'Should recommend charge during off-peak or solar peak and discharge during high-rate window with estimated savings',
#   'timestamp': '2026-03-18T01:22:58.677760'}]

# %% [markdown]
# ## 4. Evaluate Responses

# %%
import os
import json
import re
import pandas as pd
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
def evaluate_response(question, final_response, expected_response):
    """Evaluate a single response against expected criteria using an LLM judge."""
    llm = ChatOpenAI(
        model="gpt-4o-mini",
        temperature=0.0,
        base_url="https://openai.vocareum.com/v1",
        api_key=os.getenv("OPENAI_API_KEY")
    )

    prompt = f"""You are evaluating an AI energy advisor response. Score each dimension from 1 (poor) to 5 (excellent).

Question asked: {question}
Expected criteria: {expected_response}
Actual response: {final_response}

Return ONLY valid JSON with no extra text:
{{
  "accuracy": <1-5>,
  "relevance": <1-5>,
  "completeness": <1-5>,
  "usefulness": <1-5>,
  "feedback": "<one concise sentence explaining the main strength or weakness>"
}}"""

    result = llm.invoke([HumanMessage(content=prompt)])

    try:
        scores = json.loads(result.content)
    except json.JSONDecodeError:
        match = re.search(r'\{.*\}', result.content, re.DOTALL)
        scores = json.loads(match.group()) if match else {}

    # Normalise: some models return 'actionability' instead of 'usefulness'
    if "usefulness" not in scores and "actionability" in scores:
        scores["usefulness"] = scores.pop("actionability")

    # Fill any missing keys with a neutral score
    for key in ("accuracy", "relevance", "completeness", "usefulness"):
        scores.setdefault(key, 1)
    scores.setdefault("feedback", "Could not parse evaluator output")

    scores["composite_score"] = round(
        (scores["accuracy"] + scores["relevance"] + scores["completeness"] + scores["usefulness"]) / 4, 2
    )
    return scores

# %%
from langchain_core.messages import ToolMessage

def evaluate_tool_usage(messages, expected_tools):
    """Evaluate whether the expected tools were called in the agent's message history."""
    tools_used = []
    for msg in messages:
        if isinstance(msg, ToolMessage) and msg.name not in tools_used:
            tools_used.append(msg.name)

    expected = set(expected_tools)
    used = set(tools_used)
    matched = expected & used
    extra = sorted(used - expected)
    missing = sorted(expected - used)

    completeness_pct = round(len(matched) / len(expected) * 100, 1) if expected else 100.0
    appropriateness_pct = round(len(matched) / len(used) * 100, 1) if used else 0.0

    parts = []
    if missing:
        parts.append(f"Missing tools: {', '.join(missing)}.")
    if extra:
        parts.append(f"Unexpected tools used: {', '.join(extra)}.")
    if not missing and not extra:
        parts.append("All expected tools used with no unnecessary calls.")
    feedback = " ".join(parts)

    return {
        "tools_used": tools_used,
        "expected_tools": expected_tools,
        "completeness_pct": completeness_pct,
        "appropriateness_pct": appropriateness_pct,
        "missing_tools": missing,
        "extra_tools": extra,
        "feedback": feedback,
    }

# %%
def display_evaluation_report(df):
    sep = "=" * 70
    print(sep)
    print("              ECOHOME AGENT EVALUATION REPORT")
    print(sep)

    cols = ["test_id", "accuracy", "relevance", "completeness", "usefulness",
            "composite_score", "tool_completeness_pct", "tool_appropriateness_pct", "passed"]
    print(df[cols].to_string(index=False))

    print("\n--- Summary Metrics ---")
    for dim in ["accuracy", "relevance", "completeness", "usefulness", "composite_score"]:
        print(f"  Avg {dim:<22}: {df[dim].mean():.2f} / 5.0")
    print(f"  Avg tool completeness    : {df['tool_completeness_pct'].mean():.1f}%")
    print(f"  Avg tool appropriateness : {df['tool_appropriateness_pct'].mean():.1f}%")
    print(f"  Tests passed             : {df['passed'].sum()} / {len(df)}")

    print("\n--- Strengths ---")
    strong = df[df["composite_score"] >= 4.0]["test_id"].tolist()
    print("  " + (", ".join(strong) if strong else "No tests scored 4.0 or above yet."))

    print("\n--- Weaknesses ---")
    weak = df[df["composite_score"] < 3.0]["test_id"].tolist()
    print("  " + (", ".join(weak) if weak else "No tests scored below 3.0."))

    print("\n--- Recommendations ---")
    recs = []
    for dim in ["accuracy", "relevance", "completeness", "usefulness"]:
        if df[dim].mean() < 3.5:
            recs.append(f"Improve {dim} (avg {df[dim].mean():.2f}): refine the system prompt guidance for this dimension.")
    if df["tool_completeness_pct"].mean() < 60:
        low = df[df["tool_completeness_pct"] < 50]["test_id"].tolist()
        recs.append(f"Tool coverage is low in: {', '.join(low)}. Review expected_tools or strengthen tool-calling instructions.")
    if df["tool_appropriateness_pct"].mean() < 70:
        recs.append("Agent is calling tools outside the expected set. Tighten the tool descriptions or prompt.")
    if not recs:
        recs.append("Performance is solid across all dimensions. Consider adding edge-case test scenarios.")
    for r in recs:
        print(f"  - {r}")

    print(sep)


def generate_evaluation_report():
    rows = []

    for result in test_results:
        if "error" in result:
            rows.append({
                "test_id": result["test_id"],
                "accuracy": 0, "relevance": 0, "completeness": 0, "usefulness": 0,
                "composite_score": 0.0,
                "tool_completeness_pct": 0.0,
                "tool_appropriateness_pct": 0.0,
                "missing_tools": ", ".join(result["expected_tools"]),
                "response_feedback": result["error"],
                "tool_feedback": "",
                "passed": False
            })
            continue

        messages = result["response"].get("messages", [])
        final_response = messages[-1].content if messages else ""

        response_scores = evaluate_response(result["question"], final_response, result["expected_response"])
        tool_scores = evaluate_tool_usage(messages, result["expected_tools"])

        passed = response_scores["composite_score"] >= 3.0 and tool_scores["completeness_pct"] >= 50.0

        rows.append({
            "test_id": result["test_id"],
            "accuracy": response_scores["accuracy"],
            "relevance": response_scores["relevance"],
            "completeness": response_scores["completeness"],
            "usefulness": response_scores["usefulness"],
            "composite_score": response_scores["composite_score"],
            "tool_completeness_pct": tool_scores["completeness_pct"],
            "tool_appropriateness_pct": tool_scores["appropriateness_pct"],
            "missing_tools": ", ".join(tool_scores["missing_tools"]) if tool_scores["missing_tools"] else "-",
            "response_feedback": response_scores["feedback"],
            "tool_feedback": tool_scores["feedback"],
            "passed": passed
        })

    df = pd.DataFrame(rows)
    display_evaluation_report(df)
    return df

# %%
evaluation_df = generate_evaluation_report()
# Out:
# ======================================================================
#               ECOHOME AGENT EVALUATION REPORT
# ======================================================================
#              test_id  accuracy  relevance  completeness  usefulness  composite_score  tool_completeness_pct  tool_appropriateness_pct  passed
#        ev_charging_1         5          5             5           5             5.00                  100.0                     100.0    True
#         thermostat_1         5          5             4           4             4.50                   66.7                     100.0    True
#      usage_history_1         3          4             3           4             3.50                  100.0                     100.0    True
# dishwasher_savings_1         5          5             3           4             4.25                   50.0                     100.0    True
#          pool_pump_1         4          5             4           5             4.50                   50.0                     100.0    True
#     solar_forecast_1         5          5             4           5             4.75                   50.0                     100.0    True
#      hvac_heatwave_1         5          5             4           4             4.50                   66.7                     100.0    True
# laundry_scheduling_1         5          5             5           5             5.00                  100.0                     100.0    True
#     cost_breakdown_1         2          3             1           2             2.00                   50.0                     100.0   False
#   battery_strategy_1         4          5             4           4             4.25                   66.7                      50.0    True
#
# --- Summary Metrics ---
#   Avg accuracy              : 4.30 / 5.0
#   Avg relevance             : 4.70 / 5.0
#   Avg completeness          : 3.70 / 5.0
#   Avg usefulness            : 4.20 / 5.0
#   Avg composite_score       : 4.22 / 5.0
#   Avg tool completeness    : 70.0%
#   Avg tool appropriateness : 95.0%
#   Tests passed             : 9 / 10
#
# --- Strengths ---
#   ev_charging_1, thermostat_1, dishwasher_savings_1, pool_pump_1, solar_forecast_1, hvac_heatwave_1, laundry_scheduling_1, battery_strategy_1
#
# --- Weaknesses ---
#   cost_breakdown_1
#
# --- Recommendations ---
#   - Performance is solid across all dimensions. Consider adding edge-case test scenarios.
# ======================================================================
